# %% [markdown]
# ## 공공데이터포털 지하안전 데이터

# %%
import requests
import json

SERVICE_KEY = "48RysNl1ik0Yayfh1ih7lOwKPbSQmus+nhN76dcuw/5LSr4uXnBrSZEPYq5QsUWf/37wyPGCbmOawE5X2mMeBw=="
BASE_URL = "https://apis.data.go.kr/1611000/undergroundsafetyinfo"

def call_api_to_file(endpoint: str, output_filename: str, custom_params: dict):
    params = {
        "serviceKey": SERVICE_KEY,
        "pageNo": "1",
        "numOfRows": "5",
        "type": "json"
    }
    params.update(custom_params)
    url = f"{BASE_URL}/{endpoint}"
    try:
        response = requests.get(url, params=params)
        data = response.json()
        with open(f"Database/openapi/{output_filename}.json", "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
            print(f"✅ 저장 완료: {output_filename}.json")
        return f""
    except Exception as e:
        return f"❌ 오류 발생: {e}"

# %%
def get_impat_evaluation_list(start_date: str, end_date: str):
    return call_api_to_file("getImpatEvalutionList", "지하안전평가_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_impat_evaluation_info(impact_no: str):
    return call_api_to_file("getImpatEvalutionInfo", "지하안전평가_정보", {
        "impatNo": impact_no
    })

def get_small_impat_evaluation_list(start_date: str, end_date: str):
    return call_api_to_file("getSmallImpactEvalutionList", "소규모지하안전평가_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_small_impat_evaluation_info(impact_no: str):
    return call_api_to_file("getSmallImpactEvalutionInfo", "소규모지하안전평가_정보", {
        "smImpatNo": impact_no
    })

def get_post_construction_check_list(start_date: str, end_date: str):
    return call_api_to_file("getAfterUndergroundSafetyInspectionList", "착공후지하안전조사_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_post_construction_check_info(post_no: str):
    return call_api_to_file("getAfterUndergroundSafetyInspectionInfo", "착공후지하안전조사_정보", {
        "afterUndrSfNo": post_no
    })

def get_underground_facility_list(start_ymd: str, end_ymd: str):
    return call_api_to_file("getUndergroundUtilityList", "안전점검대상_지하시설물_리스트", {
        "startYmd": start_ymd,
        "endYmd": end_ymd
    })

def get_underground_facility_info(facility_no: str):
    return call_api_to_file("getUndergroundUtilityInfo", "안전점검대상_지하시설물_정보", {
        "ugrdUtilNo": facility_no
    })

def get_underground_facility_result(facility_no: str):
    return call_api_to_file("getUndergroundUtilityResult", "지하시설물_점검결과", {
        "ugrdUtilNo": facility_no
    })

def get_risk_assessment_list(start_ymd: str, end_ymd: str):
    return call_api_to_file("getSubsidenceEvalutionList", "지반침하위험도평가_리스트", {
        "startYmd": start_ymd,
        "endYmd": end_ymd
    })

def get_risk_safety_info(eval_no: str):
    return call_api_to_file("getSubsidenceEvalutionSafety", "지반침하_안전조치내용", {
        "evalNo": eval_no
    })

def get_risk_emergency_info(eval_no: str):
    return call_api_to_file("getSubsidenceEvalutionEmergency", "지반침하_응급조치내용", {
        "evalNo": eval_no
    })

def get_priority_control_list(start_date: str, end_date: str):
    return call_api_to_file("getPriorityControlTargetList", "중점관리대상_리스트", {
        "heavyYmdFrom": start_date,
        "heavyYmdTo": end_date
    })

def get_priority_control_info(control_no: str, heavy_ymd: str):
    return call_api_to_file("getPriorityControlTargetInfo", "중점관리대상_정보", {
        "heavyNo": control_no,
        "heavyYmd": heavy_ymd
    })

def get_subsidence_accident_list(start_date: str, end_date: str, lon: str, lat: str, buffer_km: str):
    return call_api_to_file("getSubsidenceList", "지반침하사고_리스트", {
        "sagoDateFrom": start_date,
        "sagoDateTo": end_date,
        "geomLon": lon,
        "geomLat": lat,
        "buffer": buffer_km
    })

def get_subsidence_accident_info(accident_no: str):
    return call_api_to_file("getSubsidenceInfo", "지반침하사고_정보", {
        "sagoNo": accident_no
    })

def get_agency_list(start_date: str, end_date: str):
    return call_api_to_file("getProfessionalInstitutionList", "전문기관_리스트", {
        "entryYmdFrom": start_date,
        "entryYmdTo": end_date
    })

def get_agency_info(corp_cd: str):
    return call_api_to_file("getProfessionalInstitutionInfo", "전문기관_정보", {
        "corpCd": corp_cd
    })

def get_agency_results(corp_cd: str):
    return call_api_to_file("getProfessionalInstitutionResultInfo", "전문기관_실적", {
        "corpCd": corp_cd
    })

def get_underground_project_list(start_date: str, end_date: str, lon: str, lat: str, buffer_km: str):
    return call_api_to_file("getUndergroundDevelopementProjectList", "지하개발사업_리스트", {
        "staPlanYmdFrom": start_date,
        "staPlanYmdTo": end_date,
        "geomLon": lon,
        "geomLat": lat,
        "buffer": buffer_km
    })

def get_underground_project_info(project_no: str):
    return call_api_to_file("getUndergroundDevelopementProjectInfo", "지하개발사업_정보", {
        "undrDevPrjctCd": project_no
    })

# %% [markdown]
# ## 실행

# %%
# 지하안전평가
get_impat_evaluation_list("20190101", "20231231")  # ✅ 지하안전평가 리스트 조회
get_impat_evaluation_info("E00234000417")  # ✅ 지하안전평가 상세 정보 조회

# 소규모지하안전평가
get_small_impat_evaluation_list("20200101", "20231231")  # ✅ 리스트
get_small_impat_evaluation_info("E00126000025")  # ✅ 상세 정보

# 착공 후 지하안전조사
get_post_construction_check_list("20200101", "20231231")  # ✅ 리스트
get_post_construction_check_info("E00234000417")  # ✅ 상세 정보

# 안전점검대상 지하시설물
get_underground_facility_list("20180101", "20231231")  # ✅ 리스트
get_underground_facility_info("E00234000417")  # ✅ 상세 정보
get_underground_facility_result("E00234000417")  # ✅ 점검 결과

# 지반침하위험도
get_risk_assessment_list("20180101", "20231231")  # ✅ 리스트
get_risk_safety_info("E00234000417")  # ✅ 안전조치 내용
get_risk_emergency_info("E00234000417")  # ✅ 응급조치 내용

# 중점관리대상
get_priority_control_list("20180101", "20191231")  # ✅ 리스트
get_priority_control_info("E00234000417", "20180822")  # ✅ 상세 정보 (heavyNo, heavyYmd)

# 지반침하사고
get_subsidence_accident_list("20180101", "20191231", "126.9780", "37.5665", "5")  # ✅ 리스트
get_subsidence_accident_info("E00234000417")  # ✅ 상세 정보

# 전문기관
get_agency_list("20180101", "20231231")  # ✅ 리스트 (entryYmdFrom, entryYmdTo)
get_agency_info("E00001")  # ✅ 상세 정보 (corpCd)
get_agency_results("E00001")  # ✅ 실적 조회 (corpCd)

# 지하개발사업
get_underground_project_list("20180101", "20191231", "126.9780", "37.5665", "5")  # ✅ 리스트
get_underground_project_info("E00234000417")  # ✅ 상세 정보
# Out:
# ✅ 저장 완료: 지하안전평가_리스트.json
# ✅ 저장 완료: 지하안전평가_정보.json
# ✅ 저장 완료: 소규모지하안전평가_리스트.json
# ✅ 저장 완료: 소규모지하안전평가_정보.json
# ✅ 저장 완료: 착공후지하안전조사_리스트.json
# ✅ 저장 완료: 착공후지하안전조사_정보.json
# ✅ 저장 완료: 안전점검대상_지하시설물_리스트.json
# ✅ 저장 완료: 안전점검대상_지하시설물_정보.json
# ✅ 저장 완료: 지하시설물_점검결과.json
# ✅ 저장 완료: 지반침하위험도평가_리스트.json
# ✅ 저장 완료: 중점관리대상_리스트.json
# ✅ 저장 완료: 중점관리대상_정보.json
# ✅ 저장 완료: 지반침하사고_리스트.json
# ✅ 저장 완료: 지반침하사고_정보.json
# ✅ 저장 완료: 지하개발사업_리스트.json
# ✅ 저장 완료: 지하개발사업_정보.json
# ''

# %% [markdown]
# ## 자동화

# %%
import os
import requests
import json
import time

SERVICE_KEY = "48RysNl1ik0Yayfh1ih7lOwKPbSQmus+nhN76dcuw/5LSr4uXnBrSZEPYq5QsUWf/37wyPGCbmOawE5X2mMeBw=="
BASE_URL = "https://apis.data.go.kr/1611000/undergroundsafetyinfo"

def fetch_all_pages(endpoint: str, filename_prefix: str, params: dict, key_path: list, max_pages=100):
    all_items = []
    page = 1

    while page <= max_pages:
        params["pageNo"] = page
        params["numOfRows"] = 1000
        params["type"] = "json"

        try:
            url = f"{BASE_URL}/{endpoint}"
            response = requests.get(url, params={**params, "serviceKey": SERVICE_KEY})
            response.raise_for_status()
            data = response.json()
        except Exception as e:
            print(f"❌ 요청 실패 (페이지 {page}): {e}")
            break

        items = data
        for key in key_path:
            items = items.get(key, [])

        if not items:
            break

        all_items.extend(items)
        if len(items) < params["numOfRows"]:
            break

        page += 1
        time.sleep(0.1)

    # 저장
    os.makedirs("Database/openapi", exist_ok=True)
    output_path = f"Database/openapi/{filename_prefix}_전체.json"
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(all_items, f, ensure_ascii=False, indent=2)
        print(f"✅ 전체 저장 완료: {output_path}")

    return all_items

# %%
fetch_all_pages(
    endpoint="getImpatEvalutionList",
    filename_prefix="지하안전평가_리스트",
    params={"sysRegDateFrom": "20180101", "sysRegDateTo": "20251231"},
    key_path=["response", "body", "items"]
)
# Out:
# ✅ 전체 저장 완료: Database/openapi/지하안전평가_리스트_전체.json
# [{'evalNo': 'E00014000001',
#   'evalNm': '제주시 연동 274-13번지 일원 주상복합시설 지하안전영향평가',
#   'maxDigDepth': '21.72',
#   'proStage': '진행중',
#   'no': '1'},
#  {'evalNo': 'E00038000001',
#   'evalNm': '성남 고등지구 자족 및 판매시설 1BL 지식산업센터 신축공사 지하안전영향평가',
#   'maxDigDepth': '23.50',
#   'proStage': '진행중',
#   'no': '2'},
#  {'evalNo': 'E00006000001',
#   'evalNm': '연산동 기업형 임대주택 계획에 따른 지하안전영향평가 및 지반조사 용역',
#   'maxDigDepth': '41.00',
#   'proStage': '진행중',
#   'no': '3'},
#  {'evalNo': 'E00038000002',
#   'evalNm': '판교 알파돔 6-1, 6-2블럭 개발사업',
#   'maxDigDepth': '34.00',
#   'proStage': '진행중',
#   'no': '4'},
#  {'evalNo': 'E00031000003',
#   'evalNm': '신천동 근린생활 및 오피스텔 신축에 따른 지하안전영향평가',
#   'maxDigDepth': '28.35',
#   'proStage': '진행중',
#   'no': '5'},
#  {'evalNo': 'E00027000002',
#   'evalNm': '김포한강신도시 MS-11-3BL 복합시설 신축공사',
#   'maxDigDepth': '23.70',
#   'proStage': '진행중',
#   'no': '6'},
#  {'evalNo': 'E00103000001',
#   'evalNm': '대구도시철도1호선 하양연장건설 지하안전영향평가 용역(긴급)',
#   'maxDigDepth': '17.59',
#   'proStage': '진행중',
#   'no': '7'},
#  {'evalNo': 'E00019000001',
#   'evalNm': '구포 봄여름가을겨울3차아파트 신축에 따른 지하안전영향평가용역',
#   'maxDigDepth': '25.00',
#   'proStage': '진행중',
#   'no': '8'},
#  {'evalNo': 'E00133000001',
#   'evalNm': '성남고등지구 자족용지 지식산업센터 신축공사 지하안전영향평가',
#   'maxDigDepth': '20.83',
#   'proStage': '진행중',
#   'no': '9'},
#  {'evalNo': 'E00075000001',
#   'evalNm': '시흥 은계지구 업무 2-4블럭 오피스텔 신축공사 지하안전영향평가',
#   'maxDigDepth': '24.45',
#   'proStage': '진행중',
#   'no': '10'},
#  {'evalNo': 'E00075000002',
#   'evalNm': '김포시 풍무지구 메트로프라임 신축공사 지하안전영향평가',
#   'maxDigDepth': '21.46',
#   'proStage': '진행중',
#   'no': '11'},
#  {'evalNo': 'E00022000002',
#   'evalNm': '파트너스 플라자 신축공사 지하안전영향평가',
#   'maxDigDepth': '35.86',
#   'proStage': '진행중',
#   'no': '12'},
#  {'evalNo': 'E00049000001',
#   'evalNm': '동탄신도시 인성 주상복합건축물(근린생활시설, 오피스텔) 신축공사',
#   'maxDigDepth': '23.00',
#   'proStage': '진행중',
#   'no': '13'},
#  {'evalNo': 'E00010000006',
#   'evalNm': '마포로1구역 제12.13지구 재개발사업',
#   'maxDigDepth': '25.25',
#   'proStage': '진행중',
#   'no': '14'},
#  {'evalNo': 'E00038000003',
#   'evalNm': '성남 판교 알파돔 6-1, 6-2블럭 개발사업(보완)',
#   'maxDigDepth': '36.95',
#   'proStage': '진행중',
#   'no': '15'},
#  {'evalNo': 'E00046000002',
#   'evalNm': '김포우리병원 증축공사 지하안전영향평가',
#   'maxDigDepth': '20.61',
#   'proStage': '진행중',
#   'no': '16'},
#  {'evalNo': 'E00099000001',
#   'evalNm': 'EX-Smartcenter 신축공사 지하안전영향평가',
#   'maxDigDepth': '24.80',
#   'proStage': '진행중',
#   'no': '17'},
#  {'evalNo': 'E00038000005',
#   'evalNm': '제주 중문 복합리조트(숙박시설) 지하안전영향평가',
#   'maxDigDepth': '22.00',
#   'proStage': '진행중',
#   'no': '18'},
#  {'evalNo': 'E00163000002',
#   'evalNm': '파주 와동동 1431-1 월드타워12차 신축공사',
#   'maxDigDepth': '15.36',
#   'proStage': '진행중',
#   'no': '19'},
#  {'evalNo': 'E00038000006',
#   'evalNm': '여수 안산동 부영아파트 1단지 신축공사 지하안전영향평가',
#   'maxDigDepth': '29.00',
#   'proStage': '작성중',
#   'no': '20'},
#  {'evalNo': 'E00038000007',
#   'evalNm': '여수 안산동 부영아파트 2단지 신축공사 지하안전영향평가',
#   'maxDigDepth': '25.00',
#   'proStage': '작성중',
#   'no': '21'},
#  {'evalNo': 'E00102000004',
#   'evalNm': 'KB국민은행 덕천동 지점 개발사업',
#   'maxDigDepth': '30.39',
#   'proStage': '진행중',
#   'no': '22'},
#  {'evalNo': 'E00075000004',
#   'evalNm': '아산시 배방지구 아산 오피스텔 신축공사 지하안전영향평가',
#   'maxDigDepth': '26.56',
#   'proStage': '진행중',
#   'no': '23'},
#  {'evalNo': 'E00134000001',
#   'evalNm': '파주운정지구 F1-P3BL 공공지원 민간임대 주택사업 지하안전영향평가',
#   'maxDigDepth': '22.96',
#   'proStage': '진행중',
#   'no': '24'},
#  {'evalNo': 'E00027000004',
#   'evalNm': '논현동 6-1 신축공사 지하안전영향평가',
#   'maxDigDepth': '22.59',
#   'proStage': '진행중',
#   'no': '25'},
#  {'evalNo': 'E00165000001',
#   'evalNm': '석유화학단지 완충저류시설 설치사업',
#   'maxDigDepth': '27.37',
#   'proStage': '진행중',
#   'no': '26'},
#  {'evalNo': 'E00154000001',
#   'evalNm': '판교 제2테크노밸리 E2-1블록 신축공사 지하안전영향평가',
#   'maxDigDepth': '36.76',
#   'proStage': '진행중',
#   'no': '27'},
#  {'evalNo': 'E00196000001',
#   'evalNm': '남제주 복합화력발전 지하안전영향평가',
#   'maxDigDepth': '22.40',
#   'proStage': '진행중',
#   'no': '28'},
#  {'evalNo': 'E00131000001',
#   'evalNm': '남원시 신정동 공동주택 신축공사',
#   'maxDigDepth': '28.10',
#   'proStage': '진행중',
#   'no': '29'},
#  {'evalNo': 'E00028000002',
#   'evalNm': '종광대2구역 주택재개발 정비사업 지하안전영향평가 용역',
#   'maxDigDepth': '32.48',
#   'proStage': '진행중',
#   'no': '30'},
#  {'evalNo': 'E00102000010',
#   'evalNm': '서초동 1339-7번지 청화오피스텔 신축공사',
#   'maxDigDepth': '33.45',
#   'proStage': '진행중',
#   'no': '31'},
#  {'evalNo': 'E00105000004',
#   'evalNm': '이천 하이닉스 M16 건설공사 반도체공장 비개착 공동구 지하안전영향평가',
#   'maxDigDepth': '21.74',
#   'proStage': '진행중',
#   'no': '32'},
#  {'evalNo': 'E00099000002',
#   'evalNm': '고양시 덕양구 도내동 972, 973번지 근린생활시설 및 오피스텔 지하안전영향평가',
#   'maxDigDepth': '20.70',
#   'proStage': '진행중',
#   'no': '33'},
#  {'evalNo': 'E00099000003',
#   'evalNm': '고양시 덕양구 도내동 974, 975번지 근린생활시설 및 오피스텔 지하안전영향평가',
#   'maxDigDepth': '20.70',
#   'proStage': '진행중',
#   'no': '34'},
#  {'evalNo': 'E00035000003',
#   'evalNm': '대구 달성군 현풍면 중리 오피스텔 신축공사 지하안전영향평가',
#   'maxDigDepth': '24.30',
#   'proStage': '진행중',
#   'no': '35'},
#  {'evalNo': 'E00086000002',
#   'evalNm': '순천향대학교 부속 새병원  지하안전영향평가 용역',
#   'maxDigDepth': '29.68',
#   'proStage': '진행중',
#   'no': '36'},
#  {'evalNo': 'E00017000004',
#   'evalNm': '당진대덕수청지구 상업시설 신축공사',
#   'maxDigDepth': '24.33',
#   'proStage': '진행중',
#   'no': '37'},
#  {'evalNo': 'E00105000006',
#   'evalNm': '이천 비상저류조 신축공사 지하안전영향평가',
#   'maxDigDepth': '24.10',
#   'proStage': '진행중',
#   'no': '38'},
#  {'evalNo': 'E00017000005',
#   'evalNm': '파주시- 명품3차 주상복합빌딩 신축공사',
#   'maxDigDepth': '13.96',
#   'proStage': '진행중',
#   'no': '39'},
#  {'evalNo': 'E00035000006',
#   'evalNm': '서울중앙지사 복합시설 개발사업 지하안전영향평가',
#   'maxDigDepth': '32.10',
#   'proStage': '진행중',
#   'no': '40'},
#  {'evalNo': 'E00065000002',
#   'evalNm': '문현3구역 주택재개발 정비사업',
#   'maxDigDepth': '20.75',
#   'proStage': '진행중',
#   'no': '41'},
#  {'evalNo': 'E00017000006',
#   'evalNm': '서초동 1327-34 복합시설 신축공사 지하안전영향평가',
#   'maxDigDepth': '29.52',
#   'proStage': '진행중',
#   'no': '42'},
#  {'evalNo': 'E00098000002',
#   'evalNm': '유성광역복합환승센터 개발사업 부지 내 복합여객터미널 사업',
#   'maxDigDepth': '39.90',
#   'proStage': '진행중',
#   'no': '43'},
#  {'evalNo': 'E00151000001',
#   'evalNm': '도시철도 환기구(감전~주례) 이설공사',
#   'maxDigDepth': '11.00',
#   'proStage': '진행중',
#   'no': '44'},
#  {'evalNo': 'E00065000007',
#   'evalNm': '봉래구역 1지구 도시환경정비사업 지하안전영향평가',
#   'maxDigDepth': '26.20',
#   'proStage': '진행중',
#   'no': '45'},
#  {'evalNo': 'E00065000008',
#   'evalNm': '식사지구 E9-7,8 복합시설 신축공사 지하안전영향평가',
#   'maxDigDepth': '27.31',
#   'proStage': '진행중',
#   'no': '46'},
#  {'evalNo': 'E00198000005',
#   'evalNm': '파주시 와동동 1469-1 신축공사',
#   'maxDigDepth': '15.95',
#   'proStage': '진행중',
#   'no': '47'},
#  {'evalNo': 'E00154000002',
#   'evalNm': '판교 제2테크노밸리 E2-1블록 신축공사 지하안전영향평가(보완)',
#   'maxDigDepth': '35.11',
#   'proStage': '진행중',
#   'no': '48'},
#  {'evalNo': 'E00223000001',
#   'evalNm': '신림동 역세권2030청년주택 신축공사 중 지반조사 및 지하안전영향평가',
#   'maxDigDepth': '27.01',
#   'proStage': '진행중',
#   'no': '49'},
#  {'evalNo': 'E00164000001',
#   'evalNm': '정자동 4-5번지 연구시설 신축공사',
#   'maxDigDepth': '37.50',
#   'proStage': '진행중',
#   'no': '50'},
#  {'evalNo': 'E00062000002',
#   'evalNm': '평택 고덕국제화계획지구 VIEW FIVE 신축공사 지하안전영향평가 용역',
#   'maxDigDepth': '24.90',
#   'proStage': '진행중',
#   'no': '51'},
#  {'evalNo': 'E00221000001',
#   'evalNm': '1, 2호선 역사시설개량공사 지하안전영향평가',
#   'maxDigDepth': '13.28',
#   'proStage': '진행중',
#   'no': '52'},
#  {'evalNo': 'E00003000004',
#   'evalNm': '345kV 신성남~동서울T/L 판교대장지구 지중화공사 지질조사, 지하안전영향평가 용역',
#   'maxDigDepth': '51.00',
#   'proStage': '진행중',
#   'no': '53'},
#  {'evalNo': 'E00200000003',
#   'evalNm': '울산 우정동 주택재개발정비사업 지반조사 및 지하안전영향평가용역',
#   'maxDigDepth': '22.56',
#   'proStage': '진행중',
#   'no': '54'},
#  {'evalNo': 'E00144000004',
#   'evalNm': '성남글로벌 ICT융합 플래닛 건립 지하안전영향평가',
#   'maxDigDepth': '21.66',
#   'proStage': '진행중',
#   'no': '55'},
#  {'evalNo': 'E00228000001',
#   'evalNm': '판교 DHNP 산학연센터 신축공사',
#   'maxDigDepth': '2296.00',
#   'proStage': '진행중',
#   'no': '56'},
#  {'evalNo': 'E00088000001',
#   'evalNm': '대구 중구 도원동 주상복합 신축공사 지하안전영향평가',
#   'maxDigDepth': '27.00',
#   'proStage': '진행중',
#   'no': '57'},
#  {'evalNo': 'E00066000003',
#   'evalNm': '대구광역시 수성구 만촌동 주상복합 신축공사 지하안전영향평가',
#   'maxDigDepth': '24.65',
#   'proStage': '진행중',
#   'no': '58'},
#  {'evalNo': 'E00006000009',
#   'evalNm': '재송2구역 주택재건축 정비사업에 따른 지하안전영향평가용역',
#   'maxDigDepth': '33.65',
#   'proStage': '진행중',
#   'no': '59'},
#  {'evalNo': 'E00204000002',
#   'evalNm': '예산 몽곡리 폐기물최종처분시설 조성사업 지하안전영향평가',
#   'maxDigDepth': '48.00',
#   'proStage': '진행중',
#   'no': '60'},
#  {'evalNo': 'E00066000004',
#   'evalNm': '대구시 수성구 만촌동 주거복합 신축공사',
#   'maxDigDepth': '27.95',
#   'proStage': '진행중',
#   'no': '61'},
#  {'evalNo': 'E00009000008',
#   'evalNm': '내부순환(만덕-센텀)도시고속화도로 민간투자사업 지하안전영향평가',
#   'maxDigDepth': '22.90',
#   'proStage': '진행중',
#   'no': '62'},
#  {'evalNo': 'E00218000002',
#   'evalNm': '대구시 달서구 대천동 공동주택 소규모 지하안전영향평가',
#   'maxDigDepth': '14.29',
#   'proStage': '진행중',
#   'no': '63'},
#  {'evalNo': 'E00038000008',
#   'evalNm': '대구광역시 수성구 복합문화시설 신축공사',
#   'maxDigDepth': '25.68',
#   'proStage': '진행중',
#   'no': '64'},
#  {'evalNo': 'E00196000002',
#   'evalNm': '경산-수성지역 전기공급시설 전력구공사(자인~시지) 외 2건 지하안전영향평가 용역중 자인-시지 구간',
#   'maxDigDepth': '23.00',
#   'proStage': '진행중',
#   'no': '65'},
#  {'evalNo': 'E00196000003',
#   'evalNm': '경산-수성지역 전기공급시설 전력구공사(자인~시지) 외 2건 지하안전영향평가 용역중 자인-시지 구간',
#   'maxDigDepth': '23.00',
#   'proStage': '진행중',
#   'no': '66'},
#  {'evalNo': 'E00066000005',
#   'evalNm': '전주에코시티 주상복합용지 1,2BL 설계용역',
#   'maxDigDepth': '26.06',
#   'proStage': '진행중',
#   'no': '67'},
#  {'evalNo': 'E00176000001',
#   'evalNm': '광주광역시 금남로 오피스텔 신축공사',
#   'maxDigDepth': '37.95',
#   'proStage': '진행중',
#   'no': '68'},
#  {'evalNo': 'E00060000004',
#   'evalNm': '대구광역시 중구 삼덕동2가 와이즈타워 주거복합 신축공사',
#   'maxDigDepth': '20.85',
#   'proStage': '진행중',
#   'no': '69'},
#  {'evalNo': 'E00226000003',
#   'evalNm': '칠성원, 경명, 상가 시장정비사업',
#   'maxDigDepth': '30.80',
#   'proStage': '진행중',
#   'no': '70'},
#  {'evalNo': 'E00006000010',
#   'evalNm': '사직1-6지구 주택재건축정비사업에 따른 지하안전영향평가 용역',
#   'maxDigDepth': '29.00',
#   'proStage': '진행중',
#   'no': '71'},
#  {'evalNo': 'E00010000010',
#   'evalNm': '고양 원흥지구 상업4-4,5블럭 오피스텔 신축공사 지하안전영향평가',
#   'maxDigDepth': '27.23',
#   'proStage': '진행중',
#   'no': '72'},
#  {'evalNo': 'E00080000002',
#   'evalNm': '여수시 학동 75, 76-5번지 숙박시설 신축공사',
#   'maxDigDepth': '24.10',
#   'proStage': '진행중',
#   'no': '73'},
#  {'evalNo': 'E00126000003',
#   'evalNm': '내당3지구 지역주택조합 주거복합시설 신축공사',
#   'maxDigDepth': '22.00',
#   'proStage': '진행중',
#   'no': '74'},
#  {'evalNo': 'E00196000004',
#   'evalNm': '경산-수성지역 전기공급시설 전력구공사(자인~시지) 외 2건 지하안전영향평가 용역중 범물-남대구 구간',
#   'maxDigDepth': '13.00',
#   'proStage': '진행중',
#   'no': '75'},
#  {'evalNo': 'E00044000002',
#   'evalNm': '다우기술컨소시엄 판교 제2사옥 신축공사',
#   'maxDigDepth': '26.00',
#   'proStage': '진행중',
#   'no': '76'},
#  {'evalNo': 'E00196000005',
#   'evalNm': '경산-수성지역 전기공급시설 전력구공사(자인~시지) 외 2건 지하안전영향평가 용역중 팔달-서침산 구간',
#   'maxDigDepth': '11.00',
#   'proStage': '진행중',
#   'no': '77'},
#  {'evalNo': 'E00196000006',
#   'evalNm': '경산-수성지역 전기공급시설 전력구공사(자인~시지) 외 2건 지하안전영향평가 용역중 팔달-서침산 구간',
#   'maxDigDepth': '11.00',
#   'proStage': '진행중',
#   'no': '78'},
#  {'evalNo': 'E00193000003',
#   'evalNm': '안양동 676-7번지 근린생활시설 신축공사 지하안전영향평가',
#   'maxDigDepth': '1988.00',
#   'proStage': '진행중',
#   'no': '79'},
#  {'evalNo': 'E00066000010',
#   'evalNm': '대구 진천동 라온프라이빗 주상복합 신축공사 지하안전영향평가',
#   'maxDigDepth': '26.00',
#   'proStage': '진행중',
#   'no': '80'},
#  {'evalNo': 'E00226000005',
#   'evalNm': '본리동 더퍼스트 주거복합 신축공사',
#   'maxDigDepth': '20.70',
#   'proStage': '진행중',
#   'no': '81'},
#  {'evalNo': 'E00097000004',
#   'evalNm': '범어동 OO주상복합 신축공사 지하안전영향평가 용역',
#   'maxDigDepth': '24.00',
#   'proStage': '진행중',
#   'no': '82'},
#  {'evalNo': 'E00043000004',
#   'evalNm': '세종특별자치시 1-5생활권 C37-3BL 관광호텔 및 근린생활시설 신축공사',
#   'maxDigDepth': '27.00',
#   'proStage': '진행중',
#   'no': '83'},
#  {'evalNo': 'E00224000001',
#   'evalNm': '오산세교 오피스텔  신축공사  소규모지하안전영향평가',
#   'maxDigDepth': '20.00',
#   'proStage': '진행중',
#   'no': '84'},
#  {'evalNo': 'E00133000003',
#   'evalNm': '대구 중구 동인동1가 주상복합 신축공사',
#   'maxDigDepth': '24.00',
#   'proStage': '진행중',
#   'no': '85'},
#  {'evalNo': 'E00194000001',
#   'evalNm': '도남지중화 사업 하천횡단 압입구간 지하안전영향평가 용역',
#   'maxDigDepth': '19.50',
#   'proStage': '진행중',
#   'no': '86'},
#  {'evalNo': 'E00029000001',
#   'evalNm': '울산역 복합환승센터주변 기반시설 정비공사 지하안전영향평가 용역',
#   'maxDigDepth': '19.16',
#   'proStage': '진행중',
#   'no': '87'},
#  {'evalNo': 'E00047000007',
#   'evalNm': '광산구 쌍암동 주상복합 신축공사',
#   'maxDigDepth': '33.00',
#   'proStage': '진행중',
#   'no': '88'},
#  {'evalNo': 'E00184000005',
#   'evalNm': '연제구 연산동(1124-25번지) 복합시설 신축공사 지하안전영향평가 용역',
#   'maxDigDepth': '24.00',
#   'proStage': '진행중',
#   'no': '89'},
#  {'evalNo': 'E00052000009',
#   'evalNm': '부산항(북항) 재개발사업지 내 상업·업무지구 D-3블럭 개발사업',
#   'maxDigDepth': '29.76',
#   'proStage': '진행중',
#   'no': '90'},
#  {'evalNo': 'E00154000017',
#   'evalNm': '대구중구 동인동 주거복합 신축공사',
#   'maxDigDepth': '1965.00',
#   'proStage': '진행중',
#   'no': '91'},
#  {'evalNo': 'E00185000002',
#   'evalNm': '안골천 우수암거 단면확장공사 지하안전영향평가',
#   'maxDigDepth': '8.00',
#   'proStage': '진행중',
#   'no': '92'},
#  {'evalNo': 'E00029000002',
#   'evalNm': '울산역 복합환승센터 주변 기반시설 정비공사 지하안전영향평가',
#   'maxDigDepth': '19.16',
#   'proStage': '진행중',
#   'no': '93'},
#  {'evalNo': 'E00099000010',
#   'evalNm': '동탄2 업무시설 1블록 1로트 업무복합시설 신축공사 지하안전영향평가서',
#   'maxDigDepth': '27.60',
#   'proStage': '진행중',
#   'no': '94'},
#  {'evalNo': 'E00092000002',
#   'evalNm': '화곡동 987-7 외2필지 오피스텔 신축공사 ',
#   'maxDigDepth': '1360.00',
#   'proStage': '진행중',
#   'no': '95'},
#  {'evalNo': 'E00019000010',
#   'evalNm': '신덕배수펌프장(터널) 지하안전영향평가',
#   'maxDigDepth': '13.00',
#   'proStage': '작성중',
#   'no': '96'},
#  {'evalNo': 'E00075000009',
#   'evalNm': '인천 검단지구 C5-1-2 오피스텔 신축공사 지하안전영향평가',
#   'maxDigDepth': '30.19',
#   'proStage': '진행중',
#   'no': '97'},
#  {'evalNo': 'E00055000018',
#   'evalNm': '하남시 망월동 355-5외 미사자족 1-1,2블럭 지식산업센터 [재]',
#   'maxDigDepth': '22.35',
#   'proStage': '승인완료',
#   'no': '98'},
#  {'evalNo': 'E00121000011',
#   'evalNm': '임마누엘 케어센터 신축공사',
#   'maxDigDepth': '30.25',
#   'proStage': '진행중',
#   'no': '99'},
#  {'evalNo': 'E00243000003',
#   'evalNm': '원주시 원동 274-40번지 일원 다바골 주택재개발 정비사업',
#   'maxDigDepth': '26.70',
#   'proStage': '작성중',
#   'no': '100'}]

# %%
response = requests.get(
    "https://apis.data.go.kr/1611000/undergroundsafetyinfo/getImpatEvalutionList",
    params={
        "serviceKey": SERVICE_KEY,
        "pageNo": 2,
        "numOfRows": 1000,
        "type": "json",
        "sysRegDateFrom": "20180101",
        "sysRegDateTo": "20251231"
    }
)
print(response.json())
# Out:
# {'response': {'header': {'resultCode': '0', 'resultMsg': 'NORMAL_CODE'}, 'numOfRows': '1000', 'pageNo': '2', 'totalCount': '2601', 'body': {'items': [{'evalNo': 'E00038000023', 'evalNm': '의왕시 고천동 375-6번지 오토갤러리 신축', 'maxDigDepth': '38.58', 'proStage': '승인완료', 'no': '101'}, {'evalNo': 'E00022000013', 'evalNm': '서울 강동구 성내동 48-6 천호 성내3구역 재개발 사업 [재]', 'maxDigDepth': '34.52', 'proStage': '승인완료', 'no': '102'}, {'evalNo': 'E00143000007', 'evalNm': '고양 덕양구 도내동 955 오피스텔 신축공사', 'maxDigDepth': '25.20', 'proStage': '승인완료', 'no': '103'}, {'evalNo': 'E00022000008', 'evalNm': '인천시 서구 청라국제도시 청라동 6-2번지 오피스텔 신축', 'maxDigDepth': '33.50', 'proStage': '진행중', 'no': '104'}, {'evalNo': 'E10008000004', 'evalNm': '서울시 강서구 등촌동 14-7번지 지식산업센터 신축', 'maxDigDepth': '26.86', 'proStage': '진행중', 'no': '105'}, {'evalNo': 'E00198000006', 'evalNm': '서울시 강서구 등촌동 631-5 일원 축산농협 종합시설 신축', 'maxDigDepth': '22.83', 'proStage': '승인완료', 'no': '106'}, {'evalNo': 'E00010000014', 'evalNm': '서울시 광진구 구의동 218-11 근린생활시설 신축', 'maxDigDepth': '21.08', 'proStage': '승인완료', 'no': '107'}, {'evalNo': 'E00080000013', 'evalNm': '서울시 구로구 신도림동 413-9 외 9필지 신축', 'maxDigDepth': '24.98', 'proStage': '승인완료', 'no': '108'}, {'evalNo': 'E00114000011', 'evalNm': '서울시 금천구 가산동 345-40번지 지식산업센터 신축[재]', 'maxDigDepth': '28.05', 'proStage': '진행중', 'no': '109'}, {'evalNo': 'E00039000002', 'evalNm': '서울시 금천구 가산동 554-2번지 지식산업센터 신축', 'maxDigDepth': '24.56', 'proStage': '진행중', 'no': '110'}, {'evalNo': 'E00055000010', 'evalNm': '서울시 금천구 독산동 292-6 외11 오피스텔 신축', 'maxDigDepth': '26.96', 'proStage': '승인완료', 'no': '111'}, {'evalNo': 'E00126000021', 'evalNm': '하남시 미사지구 자족시설12-1블럭 지식산업센터 신축공사', 'maxDigDepth': '21.23', 'proStage': '승인완료', 'no': '112'}, {'evalNo': 'E00126000014', 'evalNm': '하남시 미사지구 자족용지 13-1BL 지식산업센터 신축공사', 'maxDigDepth': '22.00', 'proStage': '승인완료', 'no': '113'}, {'evalNo': 'E00023000016', 'evalNm': '하남시 미사지구 중상3-1블럭 근린생활시설 신축', 'maxDigDepth': '22.65', 'proStage': '승인완료', 'no': '114'}, {'evalNo': 'E00190000010', 'evalNm': '서울시 영등포구 여의도동 21-4 공작상가 신축', 'maxDigDepth': '32.77', 'proStage': '승인완료', 'no': '115'}, {'evalNo': 'E00102000024', 'evalNm': '서울시 영등포구 여의도동 44-5번지 오피스텔 신축', 'maxDigDepth': '27.50', 'proStage': '승인완료', 'no': '116'}, {'evalNo': 'E00025000010', 'evalNm': '서울시 용산구 문배동 8-5번지 외6필지 오피스텔 신축', 'maxDigDepth': '33.14', 'proStage': '승인완료', 'no': '117'}, {'evalNo': 'E00091000002', 'evalNm': '서울 종로구 숭인동 1425 복합시설', 'maxDigDepth': '32.87', 'proStage': '승인완료', 'no': '118'}, {'evalNo': 'E00043000005', 'evalNm': '서울 종로구 종로5가 138-4 오피스텔 신축', 'maxDigDepth': '31.94', 'proStage': '진행중', 'no': '119'}, {'evalNo': 'E00103000003', 'evalNm': '서울 중구 묵정동 32-5 업무 및 근린생활', 'maxDigDepth': '23.50', 'proStage': '승인완료', 'no': '120'}, {'evalNo': 'E00096000004', 'evalNm': '서울 중구 충무로4가 세운 6-2-24 도시정비형 재개발사업', 'maxDigDepth': '29.86', 'proStage': '진행중', 'no': '121'}, {'evalNo': 'E00038000012', 'evalNm': '서울 중구 황학동 1257 오피스텔', 'maxDigDepth': '34.40', 'proStage': '승인완료', 'no': '122'}, {'evalNo': 'E00096000002', 'evalNm': '서울 중랑구 묵동 176-23 역세권 청년주택', 'maxDigDepth': '25.50', 'proStage': '승인완료', 'no': '123'}, {'evalNo': 'E00004000007', 'evalNm': '서울 중랑구 상봉동 91-4외 케이티앤지 복합개발', 'maxDigDepth': '30.40', 'proStage': '진행중', 'no': '124'}, {'evalNo': 'E00030000004', 'evalNm': '서울 중랑구 신내동 37 신내3지구 지식산업센터 신축공사', 'maxDigDepth': '18.25', 'proStage': '진행중', 'no': '125'}, {'evalNo': 'E00038000009', 'evalNm': '서울 현대차 특별계획구역 복합시설(GBC) 신축', 'maxDigDepth': '39.80', 'proStage': '승인완료', 'no': '126'}, {'evalNo': 'E00038000034', 'evalNm': '평택시 고덕지구 11-1-1BL 복합시설 신축공사', 'maxDigDepth': '24.10', 'proStage': '승인완료', 'no': '127'}, {'evalNo': 'E00038000039', 'evalNm': '평택시 고덕지구 11-1-2, 3블럭 복합시설 신축공사', 'maxDigDepth': '31.50', 'proStage': '승인완료', 'no': '128'}, {'evalNo': 'E00133000006', 'evalNm': '하남미사지구 중산15-2BL 근생 및 판매, 업무시설 신축공사', 'maxDigDepth': '22.47', 'proStage': '승인완료', 'no': '129'}, {'evalNo': 'E00023000026', 'evalNm': '하남미사지구 중상3-1BL 근린생활시설 신축공사', 'maxDigDepth': '22.65', 'proStage': '승인완료', 'no': '130'}, {'evalNo': 'E00066000013', 'evalNm': '남양주시 다산지금 ...

# %% [markdown]
# ## 개수 확인

# %%
import math
import requests

def get_total_pages(endpoint: str, params: dict, rows_per_page: int = 1000) -> int:
    BASE_URL = "https://apis.data.go.kr/1611000/undergroundsafetyinfo"
    SERVICE_KEY = "48RysNl1ik0Yayfh1ih7lOwKPbSQmus+nhN76dcuw/5LSr4uXnBrSZEPYq5QsUWf/37wyPGCbmOawE5X2mMeBw=="

    full_params = {
        "serviceKey": SERVICE_KEY,
        "pageNo": 1,
        "numOfRows": 1,
        "type": "json"
    }
    full_params.update(params)

    try:
        response = requests.get(f"{BASE_URL}/{endpoint}", params=full_params)
        response.raise_for_status()
        data = response.json()
        total_count = int(data["response"]["totalCount"])
        total_pages = math.ceil(total_count / rows_per_page)
        print(f"📊 전체 데이터 수: {total_count}개 → 총 {total_pages} 페이지 예상 (페이지당 {rows_per_page}개)")
        return total_pages
    except Exception as e:
        print(f"❌ 전체 페이지 수 계산 오류: {e}")
        return -1

# %%
get_total_pages(
    endpoint="getImpatEvalutionList",
    params={"sysRegDateFrom": "20180101", "sysRegDateTo": "20251231"},
    rows_per_page=1000
)
# Out:
# 📊 전체 데이터 수: 2601개 → 총 3 페이지 예상 (페이지당 1000개)
# 3
