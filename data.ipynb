# %% [markdown]
# # 공공데이터포털 지하안전 데이터

# %%
from tqdm import tqdm
import time
import requests
import json
import os

SERVICE_KEY = "48RysNl1ik0Yayfh1ih7lOwKPbSQmus+nhN76dcuw/5LSr4uXnBrSZEPYq5QsUWf/37wyPGCbmOawE5X2mMeBw=="
BASE_URL = "https://apis.data.go.kr/1611000/undergroundsafetyinfo"

def call_api_to_file(endpoint: str, output_filename: str, custom_params: dict):
    params = {
        "serviceKey": SERVICE_KEY,
        "pageNo": "1",
        "numOfRows": "1000",
        "type": "json"
    }
    params.update(custom_params)
    url = f"{BASE_URL}/{endpoint}"

    # tqdm bar for a single task
    with tqdm(total=1, desc=f"📡 {output_filename}", bar_format="{l_bar}{bar} {elapsed}s") as pbar:
        try:
            response = requests.get(url, params=params)
            data = response.json()

            os.makedirs("Database/openapi/test", exist_ok=True)
            with open(f"Database/openapi/test/{output_filename}.json", "w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

            pbar.update(1)
            print(f"✅ 저장 완료: {output_filename}.json")
            return ""
        except Exception as e:
            pbar.update(1)
            print(f"❌ 오류 발생: {e}")
            return f"❌ 오류 발생: {e}"

# %% [markdown]
# ## 각 api 호출 함수

# %%
def get_impat_evaluation_list(start_date: str, end_date: str):
    return call_api_to_file("getImpatEvalutionList", "지하안전평가_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_impat_evaluation_info(eval_no: str):
    return call_api_to_file("getImpatEvalutionInfo", "지하안전평가_정보", {
        "evalNo": eval_no
    })

def get_small_impat_evaluation_list(start_date: str, end_date: str):
    return call_api_to_file("getSmallImpactEvalutionList", "소규모지하안전평가_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_small_impat_evaluation_info(eval_no: str):
    return call_api_to_file("getSmallImpactEvalutionInfo", "소규모지하안전평가_정보", {
        "evalNo": eval_no
    })

def get_post_construction_check_list(start_date: str, end_date: str):
    return call_api_to_file("getAfterUndergroundSafetyInspectionList", "착공후지하안전조사_리스트", {
        "sysRegDateFrom": start_date,
        "sysRegDateTo": end_date
    })

def get_post_construction_check_info(eval_no: str):
    return call_api_to_file("getAfterUndergroundSafetyInspectionInfo", "착공후지하안전조사_정보", {
        "evalNo": eval_no
    })

def get_underground_facility_list(start_ymd: str, end_ymd: str):
    return call_api_to_file("getUndergroundUtilityList", "안전점검대상_지하시설물_리스트", {
        "startYmd": start_ymd,
        "endYmd": end_ymd
    })

def get_underground_facility_info(facility_no: str):
    return call_api_to_file("getUndergroundUtilityInfo", "안전점검대상_지하시설물_정보", {
        "facilNo": facility_no
    })

def get_underground_facility_result(facility_no: str):
    return call_api_to_file("getUndergroundUtilityResult", "안전점검대상_지하시설물_점검결과", {
        "facilNo": facility_no
    })

def get_risk_assessment_list(start_ymd: str, end_ymd: str):
    return call_api_to_file("getSubsidenceEvalutionList", "지반침하위험도평가_리스트", {
        "startYmd": start_ymd,
        "endYmd": end_ymd
    })

def get_risk_safety_info(eval_no: str):
    return call_api_to_file("getSubsidenceResult", "지반침하_안전조치내용", {
        "evalNo": eval_no
    })

def get_risk_emergency_info(eval_no: str):
    return call_api_to_file("getSubsidenceExpediency", "지반침하_응급조치내용", {
        "evalNo": eval_no
    })

def get_priority_control_list(start_date: str, end_date: str):
    return call_api_to_file("getPriorityControlTargetList", "중점관리대상_리스트", {
        "heavyYmdFrom": start_date,
        "heavyYmdTo": end_date
    })

def get_priority_control_info(control_no: str, heavy_ymd: str):
    return call_api_to_file("getPriorityControlTargetInfo", "중점관리대상_정보", {
        "facilNo": control_no,
        "heavyYmd": heavy_ymd
    })

def get_subsidence_accident_list(start_date: str, end_date: str):#, lon: str, lat: str, buffer_km: str):
    return call_api_to_file("getSubsidenceList", "지반침하사고_리스트", {
        "sagoDateFrom": start_date,
        "sagoDateTo": end_date,
        # "geomLon": lon,
        # "geomLat": lat,
        # "buffer": buffer_km
    })

def get_subsidence_accident_info(accident_no: str):
    return call_api_to_file("getSubsidenceInfo", "지반침하사고_정보", {
        "sagoNo": accident_no
    })

def get_agency_list(start_date: str, end_date: str):
    return call_api_to_file("getProfessionalInstituionList", "전문기관_리스트", {
        "entryYmdFrom": start_date,
        "entryYmdTo": end_date
    })

def get_agency_info(corp_cd: str):
    return call_api_to_file("getProfessionalInstituionInfo", "전문기관_정보", {
        "corpCd": corp_cd
    })

def get_agency_results(corp_cd: str):
    return call_api_to_file("getProfessionalInstituionresultInfo", "전문기관_실적", {
        "corpCd": corp_cd
    })

def get_underground_project_list(start_date: str, end_date: str):#, lon: str, lat: str, buffer_km: str):
    return call_api_to_file("getUndergroundDevelopementProjectList", "지하개발사업_리스트", {
        "staPlanYmdFrom": start_date,
        "staPlanYmdTo": end_date,
        # "geomLon": lon,
        # "geomLat": lat,
        # "buffer": buffer_km
    })

def get_underground_project_info(project_no: str):
    return call_api_to_file("getUndergroundDevelopementProjectInfo", "지하개발사업_정보", {
        "saupNo": project_no
    })

# %% [markdown]
# ### 실행

# %%
# ✅ 지하안전평가
get_impat_evaluation_list("20210101", "20211011")  # 리스트 조회
get_impat_evaluation_info("E10091000030")  # 상세 조회

# ✅ 소규모 지하안전평가
get_small_impat_evaluation_list("20210101", "20211011")  # 리스트 조회
get_small_impat_evaluation_info("E10132000007")  # 상세 조회

# ✅ 착공 후 지하안전조사
get_post_construction_check_list("20210101", "20211011")  # 리스트 조회
get_post_construction_check_info("E00017000038")  # 상세 조회

# ✅ 안전점검대상 지하시설물
get_underground_facility_list("20210101", "20211011")  # 리스트 조회
get_underground_facility_info("ELE2015-000008")  # 상세 조회
get_underground_facility_result("ELE2015-000008")  # 점검 결과 조회

# ✅ 지반침하위험도평가
get_risk_assessment_list("20210101", "20211011")  # 리스트 조회
get_risk_safety_info("E00098000019")  # 안전조치내용 조회
get_risk_emergency_info("E00098000019")  # 응급조치내용 조회

# ✅ 중점관리대상 : 제공 안하는 듯
get_priority_control_list("20210101", "20211011")  # 리스트 조회
get_priority_control_info("GAS1900-000001", "20210101")  # 상세 조회

# ✅ 지반침하사고
get_subsidence_accident_list("20210101", "20211011")#, "126.9780", "37.5665", "5")  # 리스트 조회
get_subsidence_accident_info("20220138")  # 상세 조회

# ✅ 전문기관
get_agency_list("20191017", "20191117")  # 리스트 조회
get_agency_info("E00010")  # 상세 조회
get_agency_results("E00010")  # 실적 조회

# ✅ 지하개발사업
get_underground_project_list("20210101", "20211011")# , "126.9780", "37.5665", "5")  # 리스트 조회
get_underground_project_info("20190072")  # 상세 조회
# Out:
# 📡 지하안전평가_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 지하안전평가_리스트.json
# 📡 지하안전평가_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 지하안전평가_정보.json
# 📡 소규모지하안전평가_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 소규모지하안전평가_리스트.json
# 📡 소규모지하안전평가_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 소규모지하안전평가_정보.json
# 📡 착공후지하안전조사_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 착공후지하안전조사_리스트.json
# 📡 착공후지하안전조사_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 착공후지하안전조사_정보.json
# 📡 안전점검대상_지하시설물_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 안전점검대상_지하시설물_리스트.json
# 📡 안전점검대상_지하시설물_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 안전점검대상_지하시설물_정보.json
# 📡 안전점검대상_지하시설물_점검결과: 100%|██████████ 00:00s
# ✅ 저장 완료: 안전점검대상_지하시설물_점검결과.json
# 📡 지반침하위험도평가_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 지반침하위험도평가_리스트.json
# 📡 지반침하_안전조치내용: 100%|██████████ 00:00s
# ✅ 저장 완료: 지반침하_안전조치내용.json
# 📡 지반침하_응급조치내용: 100%|██████████ 00:00s
# ✅ 저장 완료: 지반침하_응급조치내용.json
# 📡 중점관리대상_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 중점관리대상_리스트.json
# 📡 중점관리대상_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 중점관리대상_정보.json
# 📡 지반침하사고_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 지반침하사고_리스트.json
# 📡 지반침하사고_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 지반침하사고_정보.json
# 📡 전문기관_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 전문기관_리스트.json
# 📡 전문기관_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 전문기관_정보.json
# 📡 전문기관_실적: 100%|██████████ 00:00s
# ✅ 저장 완료: 전문기관_실적.json
# 📡 지하개발사업_리스트: 100%|██████████ 00:00s
# ✅ 저장 완료: 지하개발사업_리스트.json
# 📡 지하개발사업_정보: 100%|██████████ 00:00s
# ✅ 저장 완료: 지하개발사업_정보.json
# ''

# %% [markdown]
# ## 개수 및 자동수집 확인

# %%
import os
import time
import requests
import json

SERVICE_KEY = "48RysNl1ik0Yayfh1ih7lOwKPbSQmus+nhN76dcuw/5LSr4uXnBrSZEPYq5QsUWf/37wyPGCbmOawE5X2mMeBw=="
BASE_URL = "https://apis.data.go.kr/1611000/undergroundsafetyinfo"

endpoint_names = {
    "getImpatEvalutionList": "지하안전평가 리스트",
    "getSmallImpactEvalutionList": "소규모 지하안전평가 리스트",
    "getAfterUndergroundSafetyInspectionList": "착공 후 지하안전조사 리스트",
    "getUndergroundUtilityList": "안전점검대상 지하시설물 리스트",
    "getSubsidenceEvalutionList": "지반침하위험도평가 리스트",
    "getPriorityControlTargetList": "중점관리대상 리스트",
    "getSubsidenceList": "지반침하사고 리스트",
    "getProfessionalInstituionList": "전문기관 리스트",
    "getUndergroundDevelopementProjectList": "지하개발사업 리스트"
}

def fetch_until_exhausted(endpoint: str, filename_prefix: str, params: dict, key_path: list, delay: float = 0.2):
    all_items = []
    page = 0
    rows = 100

    print(f"📡 [{endpoint_names.get(endpoint, endpoint)}] 데이터 수집 시작")

    while True:
        page += 1
        request_params = {
            "serviceKey": SERVICE_KEY,
            "pageNo": page,
            "numOfRows": rows,
            "type": "json",
            **params
        }

        try:
            response = requests.get(f"{BASE_URL}/{endpoint}", params=request_params)
            response.raise_for_status()
            data = response.json()
        except Exception as e:
            print(f"❌ 에러 발생 (페이지 {page}): {e}")
            break

        # Key path 따라가며 데이터 추출
        items = data
        try:
            for key in key_path:
                if isinstance(items, dict):
                    items = items.get(key, [])
                else:
                    raise ValueError(f"⚠️ 예상과 다른 자료형 encountered at key '{key}': {type(items)}")
        except Exception as e:
            print(f"⚠️ 키 경로 추적 실패 (페이지 {page}): {e}")
            break

        if not isinstance(items, list):
            print(f"⚠️ 비정상 응답 형식 (페이지 {page}) → 중단")
            break

        if not items:
            print(f"✅ 마지막 페이지 도달 (페이지 {page})")
            break

        all_items.extend(items)
        print(f"📄 페이지 {page}: {len(items)}건 수집 (누적 {len(all_items)}건)")
        time.sleep(delay)

    # 저장
    os.makedirs("Database/openapi", exist_ok=True)
    output_path = f"Database/openapi/{filename_prefix}_전체.json"
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(all_items, f, ensure_ascii=False, indent=2)
    print(f"✅ 저장 완료: {output_path} ({len(all_items)}건)")

    return all_items

# %%
# 리스트형 엔드포인트 전체 수집 실행 코드
fetch_until_exhausted(
    endpoint="getImpatEvalutionList",
    filename_prefix="지하안전평가_리스트",
    params={"sysRegDateFrom": "20000101", "sysRegDateTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getSmallImpactEvalutionList",
    filename_prefix="소규모지하안전평가_리스트",
    params={"sysRegDateFrom": "20000101", "sysRegDateTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getAfterUndergroundSafetyInspectionList",
    filename_prefix="착공후지하안전조사_리스트",
    params={"sysRegDateFrom": "20000101", "sysRegDateTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getUndergroundUtilityList",
    filename_prefix="안전점검대상_지하시설물_리스트",
    params={"startYmd": "20000101", "endYmd": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getSubsidenceEvalutionList",
    filename_prefix="지반침하위험도평가_리스트",
    params={"startYmd": "20000101", "endYmd": "20251231"},
    key_path=["response", "body", "items"]
)

# ⚠️ 해당 엔드포인트는 종종 비정상 응답 발생 → 필요 시 주석 처리
fetch_until_exhausted(
    endpoint="getPriorityControlTargetList",
    filename_prefix="중점관리대상_리스트",
    params={"heavyYmdFrom": "20000101", "heavyYmdTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getSubsidenceList",
    filename_prefix="지반침하사고_리스트",
    params={"sagoDateFrom": "20000101", "sagoDateTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getProfessionalInstituionList",
    filename_prefix="전문기관_리스트",
    params={"entryYmdFrom": "20000101", "entryYmdTo": "20251231"},
    key_path=["response", "body", "items"]
)

fetch_until_exhausted(
    endpoint="getUndergroundDevelopementProjectList",
    filename_prefix="지하개발사업_리스트",
    params={"staPlanYmdFrom": "20000101", "staPlanYmdTo": "20251231"},
    key_path=["response", "body", "items"]
)
# Out:
# 📡 [지하안전평가 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 100건 수집 (누적 1100건)
# 📄 페이지 12: 100건 수집 (누적 1200건)
# 📄 페이지 13: 100건 수집 (누적 1300건)
# 📄 페이지 14: 100건 수집 (누적 1400건)
# 📄 페이지 15: 100건 수집 (누적 1500건)
# 📄 페이지 16: 100건 수집 (누적 1600건)
# 📄 페이지 17: 100건 수집 (누적 1700건)
# 📄 페이지 18: 100건 수집 (누적 1800건)
# 📄 페이지 19: 100건 수집 (누적 1900건)
# 📄 페이지 20: 100건 수집 (누적 2000건)
# 📄 페이지 21: 100건 수집 (누적 2100건)
# 📄 페이지 22: 100건 수집 (누적 2200건)
# 📄 페이지 23: 100건 수집 (누적 2300건)
# 📄 페이지 24: 100건 수집 (누적 2400건)
# 📄 페이지 25: 100건 수집 (누적 2500건)
# 📄 페이지 26: 100건 수집 (누적 2600건)
# 📄 페이지 27: 7건 수집 (누적 2607건)
# ⚠️ 키 경로 추적 실패 (페이지 28): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/지하안전평가_리스트_전체.json (2607건)
# 📡 [소규모 지하안전평가 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 100건 수집 (누적 1100건)
# 📄 페이지 12: 100건 수집 (누적 1200건)
# 📄 페이지 13: 100건 수집 (누적 1300건)
# 📄 페이지 14: 100건 수집 (누적 1400건)
# 📄 페이지 15: 100건 수집 (누적 1500건)
# 📄 페이지 16: 100건 수집 (누적 1600건)
# 📄 페이지 17: 100건 수집 (누적 1700건)
# 📄 페이지 18: 100건 수집 (누적 1800건)
# 📄 페이지 19: 100건 수집 (누적 1900건)
# 📄 페이지 20: 100건 수집 (누적 2000건)
# 📄 페이지 21: 100건 수집 (누적 2100건)
# 📄 페이지 22: 100건 수집 (누적 2200건)
# 📄 페이지 23: 100건 수집 (누적 2300건)
# 📄 페이지 24: 100건 수집 (누적 2400건)
# 📄 페이지 25: 100건 수집 (누적 2500건)
# 📄 페이지 26: 100건 수집 (누적 2600건)
# 📄 페이지 27: 100건 수집 (누적 2700건)
# 📄 페이지 28: 100건 수집 (누적 2800건)
# 📄 페이지 29: 100건 수집 (누적 2900건)
# 📄 페이지 30: 100건 수집 (누적 3000건)
# 📄 페이지 31: 100건 수집 (누적 3100건)
# 📄 페이지 32: 100건 수집 (누적 3200건)
# 📄 페이지 33: 100건 수집 (누적 3300건)
# 📄 페이지 34: 100건 수집 (누적 3400건)
# 📄 페이지 35: 100건 수집 (누적 3500건)
# 📄 페이지 36: 100건 수집 (누적 3600건)
# 📄 페이지 37: 100건 수집 (누적 3700건)
# 📄 페이지 38: 100건 수집 (누적 3800건)
# 📄 페이지 39: 100건 수집 (누적 3900건)
# 📄 페이지 40: 100건 수집 (누적 4000건)
# 📄 페이지 41: 100건 수집 (누적 4100건)
# 📄 페이지 42: 100건 수집 (누적 4200건)
# 📄 페이지 43: 100건 수집 (누적 4300건)
# 📄 페이지 44: 100건 수집 (누적 4400건)
# 📄 페이지 45: 100건 수집 (누적 4500건)
# 📄 페이지 46: 100건 수집 (누적 4600건)
# 📄 페이지 47: 100건 수집 (누적 4700건)
# 📄 페이지 48: 100건 수집 (누적 4800건)
# 📄 페이지 49: 100건 수집 (누적 4900건)
# 📄 페이지 50: 100건 수집 (누적 5000건)
# 📄 페이지 51: 100건 수집 (누적 5100건)
# 📄 페이지 52: 100건 수집 (누적 5200건)
# 📄 페이지 53: 32건 수집 (누적 5232건)
# ⚠️ 키 경로 추적 실패 (페이지 54): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/소규모지하안전평가_리스트_전체.json (5232건)
# 📡 [착공 후 지하안전조사 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 59건 수집 (누적 1059건)
# ⚠️ 키 경로 추적 실패 (페이지 12): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/착공후지하안전조사_리스트_전체.json (1059건)
# 📡 [안전점검대상 지하시설물 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 100건 수집 (누적 1100건)
# 📄 페이지 12: 100건 수집 (누적 1200건)
# 📄 페이지 13: 100건 수집 (누적 1300건)
# 📄 페이지 14: 100건 수집 (누적 1400건)
# 📄 페이지 15: 100건 수집 (누적 1500건)
# 📄 페이지 16: 100건 수집 (누적 1600건)
# 📄 페이지 17: 100건 수집 (누적 1700건)
# 📄 페이지 18: 100건 수집 (누적 1800건)
# 📄 페이지 19: 100건 수집 (누적 1900건)
# 📄 페이지 20: 100건 수집 (누적 2000건)
# 📄 페이지 21: 100건 수집 (누적 2100건)
# 📄 페이지 22: 100건 수집 (누적 2200건)
# 📄 페이지 23: 100건 수집 (누적 2300건)
# 📄 페이지 24: 100건 수집 (누적 2400건)
# 📄 페이지 25: 100건 수집 (누적 2500건)
# 📄 페이지 26: 100건 수집 (누적 2600건)
# 📄 페이지 27: 100건 수집 (누적 2700건)
# 📄 페이지 28: 100건 수집 (누적 2800건)
# 📄 페이지 29: 100건 수집 (누적 2900건)
# 📄 페이지 30: 100건 수집 (누적 3000건)
# 📄 페이지 31: 100건 수집 (누적 3100건)
# 📄 페이지 32: 100건 수집 (누적 3200건)
# 📄 페이지 33: 100건 수집 (누적 3300건)
# 📄 페이지 34: 100건 수집 (누적 3400건)
# 📄 페이지 35: 100건 수집 (누적 3500건)
# 📄 페이지 36: 100건 수집 (누적 3600건)
# 📄 페이지 37: 100건 수집 (누적 3700건)
# 📄 페이지 38: 100건 수집 (누적 3800건)
# 📄 페이지 39: 100건 수집 (누적 3900건)
# 📄 페이지 40: 100건 수집 (누적 4000건)
# 📄 페이지 41: 100건 수집 (누적 4100건)
# 📄 페이지 42: 100건 수집 (누적 4200건)
# 📄 페이지 43: 100건 수집 (누적 4300건)
# 📄 페이지 44: 100건 수집 (누적 4400건)
# 📄 페이지 45: 100건 수집 (누적 4500건)
# 📄 페이지 46: 100건 수집 (누적 4600건)
# 📄 페이지 47: 100건 수집 (누적 4700건)
# 📄 페이지 48: 100건 수집 (누적 4800건)
# 📄 페이지 49: 100건 수집 (누적 4900건)
# 📄 페이지 50: 100건 수집 (누적 5000건)
# 📄 페이지 51: 100건 수집 (누적 5100건)
# 📄 페이지 52: 100건 수집 (누적 5200건)
# 📄 페이지 53: 100건 수집 (누적 5300건)
# 📄 페이지 54: 100건 수집 (누적 5400건)
# 📄 페이지 55: 100건 수집 (누적 5500건)
# 📄 페이지 56: 100건 수집 (누적 5600건)
# 📄 페이지 57: 100건 수집 (누적 5700건)
# 📄 페이지 58: 100건 수집 (누적 5800건)
# 📄 페이지 59: 100건 수집 (누적 5900건)
# 📄 페이지 60: 100건 수집 (누적 6000건)
# 📄 페이지 61: 100건 수집 (누적 6100건)
# 📄 페이지 62: 100건 수집 (누적 6200건)
# 📄 페이지 63: 66건 수집 (누적 6266건)
# ⚠️ 키 경로 추적 실패 (페이지 64): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/지하시설물_리스트_전체.json (6266건)
# 📡 [지반침하위험도평가 리스트] 데이터 수집 시작
# 📄 페이지 1: 10건 수집 (누적 10건)
# ⚠️ 키 경로 추적 실패 (페이지 2): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/지반침하위험도평가_리스트_전체.json (10건)
# 📡 [중점관리대상 리스트] 데이터 수집 시작
# ⚠️ 키 경로 추적 실패 (페이지 1): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/중점관리대상_리스트_전체.json (0건)
# 📡 [지반침하사고 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 100건 수집 (누적 1100건)
# 📄 페이지 12: 100건 수집 (누적 1200건)
# 📄 페이지 13: 100건 수집 (누적 1300건)
# 📄 페이지 14: 100건 수집 (누적 1400건)
# 📄 페이지 15: 51건 수집 (누적 1451건)
# ⚠️ 키 경로 추적 실패 (페이지 16): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/지반침하사고_리스트_전체.json (1451건)
# 📡 [전문기관 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 94건 수집 (누적 394건)
# ⚠️ 키 경로 추적 실패 (페이지 5): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/전문기관_리스트_전체.json (394건)
# 📡 [지하개발사업 리스트] 데이터 수집 시작
# 📄 페이지 1: 100건 수집 (누적 100건)
# 📄 페이지 2: 100건 수집 (누적 200건)
# 📄 페이지 3: 100건 수집 (누적 300건)
# 📄 페이지 4: 100건 수집 (누적 400건)
# 📄 페이지 5: 100건 수집 (누적 500건)
# 📄 페이지 6: 100건 수집 (누적 600건)
# 📄 페이지 7: 100건 수집 (누적 700건)
# 📄 페이지 8: 100건 수집 (누적 800건)
# 📄 페이지 9: 100건 수집 (누적 900건)
# 📄 페이지 10: 100건 수집 (누적 1000건)
# 📄 페이지 11: 100건 수집 (누적 1100건)
# 📄 페이지 12: 100건 수집 (누적 1200건)
# 📄 페이지 13: 100건 수집 (누적 1300건)
# 📄 페이지 14: 100건 수집 (누적 1400건)
# 📄 페이지 15: 100건 수집 (누적 1500건)
# 📄 페이지 16: 100건 수집 (누적 1600건)
# 📄 페이지 17: 100건 수집 (누적 1700건)
# 📄 페이지 18: 100건 수집 (누적 1800건)
# 📄 페이지 19: 100건 수집 (누적 1900건)
# 📄 페이지 20: 100건 수집 (누적 2000건)
# 📄 페이지 21: 100건 수집 (누적 2100건)
# 📄 페이지 22: 100건 수집 (누적 2200건)
# 📄 페이지 23: 100건 수집 (누적 2300건)
# 📄 페이지 24: 100건 수집 (누적 2400건)
# 📄 페이지 25: 100건 수집 (누적 2500건)
# 📄 페이지 26: 100건 수집 (누적 2600건)
# 📄 페이지 27: 100건 수집 (누적 2700건)
# 📄 페이지 28: 100건 수집 (누적 2800건)
# 📄 페이지 29: 100건 수집 (누적 2900건)
# 📄 페이지 30: 100건 수집 (누적 3000건)
# 📄 페이지 31: 100건 수집 (누적 3100건)
# 📄 페이지 32: 100건 수집 (누적 3200건)
# 📄 페이지 33: 100건 수집 (누적 3300건)
# 📄 페이지 34: 100건 수집 (누적 3400건)
# 📄 페이지 35: 100건 수집 (누적 3500건)
# 📄 페이지 36: 100건 수집 (누적 3600건)
# 📄 페이지 37: 100건 수집 (누적 3700건)
# 📄 페이지 38: 100건 수집 (누적 3800건)
# 📄 페이지 39: 100건 수집 (누적 3900건)
# 📄 페이지 40: 100건 수집 (누적 4000건)
# 📄 페이지 41: 100건 수집 (누적 4100건)
# 📄 페이지 42: 100건 수집 (누적 4200건)
# 📄 페이지 43: 100건 수집 (누적 4300건)
# 📄 페이지 44: 100건 수집 (누적 4400건)
# 📄 페이지 45: 100건 수집 (누적 4500건)
# 📄 페이지 46: 100건 수집 (누적 4600건)
# 📄 페이지 47: 100건 수집 (누적 4700건)
# 📄 페이지 48: 100건 수집 (누적 4800건)
# 📄 페이지 49: 100건 수집 (누적 4900건)
# 📄 페이지 50: 100건 수집 (누적 5000건)
# 📄 페이지 51: 100건 수집 (누적 5100건)
# 📄 페이지 52: 100건 수집 (누적 5200건)
# 📄 페이지 53: 100건 수집 (누적 5300건)
# 📄 페이지 54: 100건 수집 (누적 5400건)
# 📄 페이지 55: 100건 수집 (누적 5500건)
# 📄 페이지 56: 100건 수집 (누적 5600건)
# 📄 페이지 57: 100건 수집 (누적 5700건)
# 📄 페이지 58: 100건 수집 (누적 5800건)
# 📄 페이지 59: 100건 수집 (누적 5900건)
# 📄 페이지 60: 100건 수집 (누적 6000건)
# 📄 페이지 61: 100건 수집 (누적 6100건)
# 📄 페이지 62: 100건 수집 (누적 6200건)
# 📄 페이지 63: 100건 수집 (누적 6300건)
# 📄 페이지 64: 100건 수집 (누적 6400건)
# 📄 페이지 65: 100건 수집 (누적 6500건)
# 📄 페이지 66: 100건 수집 (누적 6600건)
# 📄 페이지 67: 100건 수집 (누적 6700건)
# 📄 페이지 68: 100건 수집 (누적 6800건)
# 📄 페이지 69: 100건 수집 (누적 6900건)
# 📄 페이지 70: 100건 수집 (누적 7000건)
# 📄 페이지 71: 100건 수집 (누적 7100건)
# 📄 페이지 72: 100건 수집 (누적 7200건)
# 📄 페이지 73: 100건 수집 (누적 7300건)
# 📄 페이지 74: 100건 수집 (누적 7400건)
# 📄 페이지 75: 100건 수집 (누적 7500건)
# 📄 페이지 76: 94건 수집 (누적 7594건)
# ⚠️ 키 경로 추적 실패 (페이지 77): ⚠️ 예상과 다른 자료형 encountered at key 'items': <class 'list'>
# ✅ 저장 완료: Database/openapi/지하개발사업_리스트_전체.json (7594건)
# [{'saupNo': '20180001',
#   'saupNm': '고색동 1181-3번지 근린생활시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '16.54',
#   'no': '1'},
#  {'saupNo': '20180002',
#   'saupNm': '제주 연동 주상복합PJ',
#   'proStage': '보완회신',
#   'maxDigDepth': '21.72',
#   'no': '2'},
#  {'saupNo': '20180044',
#   'saupNm': '천안 청수지구 548-1외 1필지 복합업무시설 신축공사',
#   'proStage': '승인완료',
#   'maxDigDepth': '16.00',
#   'no': '3'},
#  {'saupNo': '20180045',
#   'saupNm': '권선동 1011-15 오피스텔 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '16.60',
#   'no': '4'},
#  {'saupNo': '20180046',
#   'saupNm': '인계동 1036-13번지 도시형생활주택 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '17.60',
#   'no': '5'},
#  {'saupNo': '20180047',
#   'saupNm': '김포시 구래동 6878-2 업무지구 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.84',
#   'no': '6'},
#  {'saupNo': '20180048',
#   'saupNm': '성남 판교대장 도시개발구역 A11BL 공동주택 신축공사 소규모 지하안전영향평가',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.86',
#   'no': '7'},
#  {'saupNo': '20180049',
#   'saupNm': '성남 판교대장 도시개발구역 A12BL 공동주택 신축공사 소규모 지하안전영향평가',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.69',
#   'no': '8'},
#  {'saupNo': '20180050',
#   'saupNm': '성남 판교대장 도시개발구역 A1BL 공동주택 신축공사 소규모 지하안전영향평가',
#   'proStage': '협의요청',
#   'maxDigDepth': '14.20',
#   'no': '9'},
#  {'saupNo': '20180051',
#   'saupNm': '성남 판교대장 도시개발구역 A2BL 공동주택 신축공사 소규모 지하안전영향평가',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.30',
#   'no': '10'},
#  {'saupNo': '20180052',
#   'saupNm': '경산시 중방동 897 주차전용건축물 신축공사',
#   'proStage': '협의내용반영확인',
#   'maxDigDepth': '19.50',
#   'no': '11'},
#  {'saupNo': '20180053',
#   'saupNm': '위례택지개발 사업지구 C2-7블럭 복합시설 개발사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '17.61',
#   'no': '12'},
#  {'saupNo': '20180054',
#   'saupNm': '명동 센터포인트 복합시설 개발사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.67',
#   'no': '13'},
#  {'saupNo': '20180055',
#   'saupNm': '수성구 상동 근린생활시설 및 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.95',
#   'no': '14'},
#  {'saupNo': '20180056',
#   'saupNm': '성남 고등지구 자족 및 판매시설 1BL 지식산업센터 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '23.50',
#   'no': '15'},
#  {'saupNo': '20180059',
#   'saupNm': '여수덕충동2037-2오피스텔신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '19.75',
#   'no': '16'},
#  {'saupNo': '20180060',
#   'saupNm': '속초시 영랑동 생활숙박 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '17.26',
#   'no': '17'},
#  {'saupNo': '20180061',
#   'saupNm': '용호동 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.19',
#   'no': '18'},
#  {'saupNo': '20180062',
#   'saupNm': '연산동 기업형 임대주택 개발사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '41.00',
#   'no': '19'},
#  {'saupNo': '20180063',
#   'saupNm': '구례군 백련리 공동주택 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '23.67',
#   'no': '20'},
#  {'saupNo': '20180064',
#   'saupNm': '성남 판교 알파돔 6-1, 6-2블럭 개발사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '34.00',
#   'no': '21'},
#  {'saupNo': '20180065',
#   'saupNm': '속초시 교동 986-3번지 일대 생활숙박시설 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '19.86',
#   'no': '22'},
#  {'saupNo': '20180066',
#   'saupNm': '신안동 국제미소래아파트 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '11.90',
#   'no': '23'},
#  {'saupNo': '20180067',
#   'saupNm': '제주시 연동 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.40',
#   'no': '24'},
#  {'saupNo': '20180068',
#   'saupNm': '대구광역시 달서구 감삼동 와이즈 타워 주상복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '18.35',
#   'no': '25'},
#  {'saupNo': '20180069',
#   'saupNm': '시흥 장현지구 6BL 복합상업시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '16.51',
#   'no': '26'},
#  {'saupNo': '20180070',
#   'saupNm': '대치동 1008 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.18',
#   'no': '27'},
#  {'saupNo': '20180071',
#   'saupNm': '성남 판교 대장지구 A3BL 공동주택 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '11.26',
#   'no': '28'},
#  {'saupNo': '20180072',
#   'saupNm': '죽전역 동화 I - WISH 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '15.44',
#   'no': '29'},
#  {'saupNo': '20180073',
#   'saupNm': '아산시 온천동 공동주택 복합빌딩 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '15.00',
#   'no': '30'},
#  {'saupNo': '20180074',
#   'saupNm': '성남 판교대장 도시개발구역 A7, 8BL 공동주택 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '18.10',
#   'no': '31'},
#  {'saupNo': '20180075',
#   'saupNm': '진해동부맑은물재생센터 증설사업(2단계)',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.75',
#   'no': '32'},
#  {'saupNo': '20180076',
#   'saupNm': '부천옥길지구 자족3-2, 3-3 지식산업센터 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.06',
#   'no': '33'},
#  {'saupNo': '20180077',
#   'saupNm': '아산 탕정지구 5-1BL 오피스복합빌딩 개발PJT',
#   'proStage': '협의결과통보',
#   'maxDigDepth': '16.43',
#   'no': '34'},
#  {'saupNo': '20180078',
#   'saupNm': '부산 수영구 민락동 D7-10~12 복합시설 개발계획',
#   'proStage': '보완요청',
#   'maxDigDepth': '18.21',
#   'no': '35'},
#  {'saupNo': '20180079',
#   'saupNm': '나라키움 서대문세무서 개발사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '14.00',
#   'no': '36'},
#  {'saupNo': '20180080',
#   'saupNm': '성남 판교대장 도시개발사업지구 A6BL 공동주택 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.06',
#   'no': '37'},
#  {'saupNo': '20180081',
#   'saupNm': '동구 신천동 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '28.35',
#   'no': '38'},
#  {'saupNo': '20180082',
#   'saupNm': '대구국가산업단지 A2-1블럭 대방 노블랜드 아파트 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.70',
#   'no': '39'},
#  {'saupNo': '20180083',
#   'saupNm': '제주시 노형동 숙박시설 신축공사',
#   'proStage': '검토결과 회신',
#   'maxDigDepth': '10.70',
#   'no': '40'},
#  {'saupNo': '20180085',
#   'saupNm': '강릉 사천항 생활형숙박시설 개발사업',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '13.75',
#   'no': '41'},
#  {'saupNo': '20180086',
#   'saupNm': '춘천농협 NH타운 개발사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.91',
#   'no': '42'},
#  {'saupNo': '20180087',
#   'saupNm': '이천하이닉스 16동 반도체공장외 2건',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.00',
#   'no': '43'},
#  {'saupNo': '20180088',
#   'saupNm': '마포로1구역 제12.13지구 재개발사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '25.25',
#   'no': '44'},
#  {'saupNo': '20180089',
#   'saupNm': '대구 신암동 에일린의뜰 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '14.45',
#   'no': '45'},
#  {'saupNo': '20180090',
#   'saupNm': '아산탕정지구 3-G1블럭 도시형생활주택 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '14.36',
#   'no': '46'},
#  {'saupNo': '20180092',
#   'saupNm': '경기도 성남 고등 C-1BL 주상복합 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '11.90',
#   'no': '47'},
#  {'saupNo': '20180093',
#   'saupNm': '남구B-14구역 주택재개발정비사업',
#   'proStage': '보완요청',
#   'maxDigDepth': '17.70',
#   'no': '48'},
#  {'saupNo': '20180094',
#   'saupNm': '경기도 성남 고등 C-2BL 주상복합 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '11.70',
#   'no': '49'},
#  {'saupNo': '20180095',
#   'saupNm': '경기도 성남 고등 C-3BL 주상복합 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '11.30',
#   'no': '50'},
#  {'saupNo': '20180096',
#   'saupNm': '김포한강신도시 MS-11-3BL 복합시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '23.70',
#   'no': '51'},
#  {'saupNo': '20180097',
#   'saupNm': '역삼동790-9 주상복합시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.05',
#   'no': '52'},
#  {'saupNo': '20180098',
#   'saupNm': '서울특별시 강남구 대치동891-63번지 오피스텔신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.61',
#   'no': '53'},
#  {'saupNo': '20180099',
#   'saupNm': '서울특별시 강남구 대치동 891-38번지 오피스텔신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.61',
#   'no': '54'},
#  {'saupNo': '20180100',
#   'saupNm': '대구 도시철도1호선 하양연장건설 지하안전영향평가용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.59',
#   'no': '55'},
#  {'saupNo': '20180101',
#   'saupNm': '수락산외 1역 승강편의시설 설치공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.34',
#   'no': '56'},
#  {'saupNo': '20180102',
#   'saupNm': '경기도 안양시 호계동 949-9번지 일원 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '21.46',
#   'no': '57'},
#  {'saupNo': '20180103',
#   'saupNm': '오산 세교택지개발지구 자족3BL 지식산업센터 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '14.20',
#   'no': '58'},
#  {'saupNo': '20180104',
#   'saupNm': '하남 미사지구 자족시설용지 12-2,3BL 지식산업센터 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '19.74',
#   'no': '59'},
#  {'saupNo': '20180105',
#   'saupNm': '여수시 학동 장미아파트지역주택조합아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.86',
#   'no': '60'},
#  {'saupNo': '20180106',
#   'saupNm': '화성동탄2신도시 일상 11BL 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '36.00',
#   'no': '61'},
#  {'saupNo': '20180107',
#   'saupNm': '화성동탄2신도시 일상 12BL 복합시설 신축공사 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '36.05',
#   'no': '62'},
#  {'saupNo': '20180108',
#   'saupNm': '논현동 236-7 업무시설',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.90',
#   'no': '63'},
#  {'saupNo': '20180109',
#   'saupNm': '플러스시네마 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '15.90',
#   'no': '64'},
#  {'saupNo': '20180110',
#   'saupNm': '경기도 부천시 원미동 지식산업센타 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.78',
#   'no': '65'},
#  {'saupNo': '20180111',
#   'saupNm': '심곡동 아파트 및 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.00',
#   'no': '66'},
#  {'saupNo': '20180112',
#   'saupNm': '안양동 199번지 지식산업센터 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '18.46',
#   'no': '67'},
#  {'saupNo': '20180113',
#   'saupNm': '성남고등지구 자족용지 지식산업센터 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '20.83',
#   'no': '68'},
#  {'saupNo': '20180114',
#   'saupNm': '구포3차 봄여름가을겨울 아파트 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '25.00',
#   'no': '69'},
#  {'saupNo': '20180115',
#   'saupNm': '용인시 수지구 풍덕천동 교육연구시설',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.21',
#   'no': '70'},
#  {'saupNo': '20180117',
#   'saupNm': '수성 범어W 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.40',
#   'no': '71'},
#  {'saupNo': '20180118',
#   'saupNm': '안양 아이에스 비즈타워 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.42',
#   'no': '72'},
#  {'saupNo': '20180119',
#   'saupNm': '금천구 가산동 345-24 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.80',
#   'no': '73'},
#  {'saupNo': '20180120',
#   'saupNm': '영도구 동삼하리 도시개발사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.86',
#   'no': '74'},
#  {'saupNo': '20180121',
#   'saupNm': '서밋 더 크로스 흥덕 복합상업시설',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.71',
#   'no': '75'},
#  {'saupNo': '20180122',
#   'saupNm': '속초시 조양동 1111-1 생활숙박시설 신축공사',
#   'proStage': '협의결과통보',
#   'maxDigDepth': '19.53',
#   'no': '76'},
#  {'saupNo': '20180123',
#   'saupNm': '시흥 은계지구 근린생활시설 및 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.45',
#   'no': '77'},
#  {'saupNo': '20180124',
#   'saupNm': '울산 중앙병원 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.01',
#   'no': '78'},
#  {'saupNo': '20180125',
#   'saupNm': '안중계통 송수관로 복선화 매설공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '11.47',
#   'no': '79'},
#  {'saupNo': '20180126',
#   'saupNm': '삼성에이아이센터(지식산업센터)',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '12.66',
#   'no': '80'},
#  {'saupNo': '20180127',
#   'saupNm': '수원 광교 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.60',
#   'no': '81'},
#  {'saupNo': '20180128',
#   'saupNm': '대구 중구 동문동 오피스텔 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '19.95',
#   'no': '82'},
#  {'saupNo': '20180129',
#   'saupNm': '시흥 은계지구 업무 3-1,2 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.35',
#   'no': '83'},
#  {'saupNo': '20180130',
#   'saupNm': '인천검단신도시 AB16BL 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.89',
#   'no': '84'},
#  {'saupNo': '20180131',
#   'saupNm': '양산 중부동 서린 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.75',
#   'no': '85'},
#  {'saupNo': '20180132',
#   'saupNm': '암센터 소규모지하안전영향평가',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '15.90',
#   'no': '86'},
#  {'saupNo': '20180133',
#   'saupNm': '의왕시 내손동 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.16',
#   'no': '87'},
#  {'saupNo': '20180134',
#   'saupNm': '(가칭)파트너스플라자 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '35.86',
#   'no': '88'},
#  {'saupNo': '20180135',
#   'saupNm': '강서구 화곡동 1111번지 외 1필지 주상복합건물 신축공사',
#   'proStage': '평가서결재중',
#   'maxDigDepth': '19.00',
#   'no': '89'},
#  {'saupNo': '20180136',
#   'saupNm': '청수지구 일반상업시설 용지 CA타워 신축공사',
#   'proStage': '협의결과통보',
#   'maxDigDepth': '19.76',
#   'no': '90'},
#  {'saupNo': '20180137',
#   'saupNm': '파주 삼융시네마',
#   'proStage': '협의요청',
#   'maxDigDepth': '13.71',
#   'no': '91'},
#  {'saupNo': '20180138',
#   'saupNm': '동탄신도시 인성 주상복합건축물(근린생활시설, 오피스텔)신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '23.00',
#   'no': '92'},
#  {'saupNo': '20180139',
#   'saupNm': '동탄2 택지개발지구 42-1 와우스퀘어1 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '16.46',
#   'no': '93'},
#  {'saupNo': '20180140',
#   'saupNm': '동탄2 택지개발지구 43-1 와우스퀘어3 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.06',
#   'no': '94'},
#  {'saupNo': '20180141',
#   'saupNm': '동탄2 택지개발지구 43-4 와우스퀘어4 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '17.60',
#   'no': '95'},
#  {'saupNo': '20180142',
#   'saupNm': '시립 마포실버케어센터 건립공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '12.45',
#   'no': '96'},
#  {'saupNo': '20180143',
#   'saupNm': '황구지천 공공하수처리시설 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '15.00',
#   'no': '97'},
#  {'saupNo': '20180144',
#   'saupNm': '죽곡1오수중계펌프장이설사업 소규모지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.50',
#   'no': '98'},
#  {'saupNo': '20180145',
#   'saupNm': '다산 진건지구 으뜸 웰타워 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.86',
#   'no': '99'},
#  {'saupNo': '20180146',
#   'saupNm': '다산진건지구 업무3-1BL 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.92',
#   'no': '100'},
#  {'saupNo': '20180147',
#   'saupNm': '제주시 이도이동 1066-4 외 1필지 주상복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.40',
#   'no': '101'},
#  {'saupNo': '20180148',
#   'saupNm': '호계온천 주변지구 주택재개발 정비사업(소규모 지하안전영향평가)',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.50',
#   'no': '102'},
#  {'saupNo': '20180149',
#   'saupNm': '성남 판교 알파돔 6-1, 6-2블럭 개발사업(보완)',
#   'proStage': '제출완료',
#   'maxDigDepth': '36.95',
#   'no': '103'},
#  {'saupNo': '20180150',
#   'saupNm': '군포시 당동 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.53',
#   'no': '104'},
#  {'saupNo': '20180151',
#   'saupNm': '부산 서면 드림아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.00',
#   'no': '105'},
#  {'saupNo': '20180153',
#   'saupNm': '송산그린시티 폴리프라자1 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.68',
#   'no': '106'},
#  {'saupNo': '20180154',
#   'saupNm': '안산시 수암동 500-1번지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.76',
#   'no': '107'},
#  {'saupNo': '20180155',
#   'saupNm': '고양시 원흥동 634-4번지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.87',
#   'no': '108'},
#  {'saupNo': '20180156',
#   'saupNm': '속초시 중앙동 468-17 일원 생활숙박시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.91',
#   'no': '109'},
#  {'saupNo': '20180157',
#   'saupNm': '김포시 구래동 6871-57 근생 및 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.36',
#   'no': '110'},
#  {'saupNo': '20180158',
#   'saupNm': '안양냉천 주거환경개선사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '14.50',
#   'no': '111'},
#  {'saupNo': '20180159',
#   'saupNm': '궁내동 258-16 자동차관련시설',
#   'proStage': '협의요청',
#   'maxDigDepth': '13.60',
#   'no': '112'},
#  {'saupNo': '20180160',
#   'saupNm': '김포한강신도시 자족시설용지 MS10-2 근린생활시설 및 오피스텔',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.95',
#   'no': '113'},
#  {'saupNo': '20180161',
#   'saupNm': '부산 수영구 민락동 D7-10~12 복합시설 개발계획',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.21',
#   'no': '114'},
#  {'saupNo': '20180162',
#   'saupNm': '다산신도시 진건지구 자족용지 3BL 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.00',
#   'no': '115'},
#  {'saupNo': '20180163',
#   'saupNm': '블루오션별내 지식산업센터 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '17.26',
#   'no': '116'},
#  {'saupNo': '20180164',
#   'saupNm': '광명사거리역 승강편의시설 설치공사(34공구) 소규모 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '11.00',
#   'no': '117'},
#  {'saupNo': '20180165',
#   'saupNm': '블루오션한강 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.06',
#   'no': '118'},
#  {'saupNo': '20180166',
#   'saupNm': '먹골역 승강편의시설 설치공사 소규모 지하안전영향평가 용역(37공구)',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.00',
#   'no': '119'},
#  {'saupNo': '20180167',
#   'saupNm': '가산디지털단지역 4번 출입구 확장공사 소규모 지하안전영향평가',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '12.00',
#   'no': '120'},
#  {'saupNo': '20180168',
#   'saupNm': '신흥동 2506-1 오피스텔 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '17.06',
#   'no': '121'},
#  {'saupNo': '20180169',
#   'saupNm': '아산 탕정지구 5-1-1BL 업무복합빌딩 개발PJT',
#   'proStage': '보완요청',
#   'maxDigDepth': '19.80',
#   'no': '122'},
#  {'saupNo': '20180170',
#   'saupNm': '김포우리병원 증축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '20.61',
#   'no': '123'},
#  {'saupNo': '20180171',
#   'saupNm': '용인시 역북동 746 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.60',
#   'no': '124'},
#  {'saupNo': '20180172',
#   'saupNm': '상대원동 145-3번지 지신산업센터 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '18.56',
#   'no': '125'},
#  {'saupNo': '20180173',
#   'saupNm': '월곡배수지 건설공사(2단계)',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.25',
#   'no': '126'},
#  {'saupNo': '20180174',
#   'saupNm': '강서구 화곡동 1111번지 외 1필지 주상복합건물 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.00',
#   'no': '127'},
#  {'saupNo': '20180175',
#   'saupNm': '김포 신곡6지구 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.26',
#   'no': '128'},
#  {'saupNo': '20180176',
#   'saupNm': 'EX-Smart Center 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.80',
#   'no': '129'},
#  {'saupNo': '20180177',
#   'saupNm': '수원역 엘리시아 주상복합 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '19.00',
#   'no': '130'},
#  {'saupNo': '20180178',
#   'saupNm': '블루오션미사 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.70',
#   'no': '131'},
#  {'saupNo': '20180179',
#   'saupNm': '노형동 904-1번지 생활숙박시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.20',
#   'no': '132'},
#  {'saupNo': '20180180',
#   'saupNm': '이천 마장지구 근린생활시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '16.71',
#   'no': '133'},
#  {'saupNo': '20180181',
#   'saupNm': '동탄2 제14중 이음터 건립공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.74',
#   'no': '134'},
#  {'saupNo': '20180182',
#   'saupNm': '부산국제아트센터',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.20',
#   'no': '135'},
#  {'saupNo': '20180183',
#   'saupNm': '제주 중문 복합리조트[숙박시설] 신축사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.00',
#   'no': '136'},
#  {'saupNo': '20180184',
#   'saupNm': '송정동 문화집회시설 및 숙박시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.11',
#   'no': '137'},
#  {'saupNo': '20180185',
#   'saupNm': '파주 와동동 1431-1 월드타워12차 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.36',
#   'no': '138'},
#  {'saupNo': '20180186',
#   'saupNm': '김포풍무2지구 26블럭2로트',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '16.00',
#   'no': '139'},
#  {'saupNo': '20180187',
#   'saupNm': '경기도 성남시 중원구 여수동 190번지 근린상가 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '16.86',
#   'no': '140'},
#  {'saupNo': '20180189',
#   'saupNm': '부산광역시 부산진구 부암동 304-14번지 일원 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.90',
#   'no': '141'},
#  {'saupNo': '20180190',
#   'saupNm': '덕천 2구역 재건축 정비사업',
#   'proStage': '승인완료',
#   'maxDigDepth': '11.70',
#   'no': '142'},
#  {'saupNo': '20180191',
#   'saupNm': '파주운정 F1-P3BL 공공지원 민간임대주택',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.96',
#   'no': '143'},
#  {'saupNo': '20180192',
#   'saupNm': '여수 안산동 부영아파트 1단지 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '29.00',
#   'no': '144'},
#  {'saupNo': '20180193',
#   'saupNm': '여수 안산동 부영아파트 2단지 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '25.00',
#   'no': '145'},
#  {'saupNo': '20180194',
#   'saupNm': '단대오거리역 승강편의시설 설치공사 소규모 지하안전영향평가 용역(35공구)',
#   'proStage': '협의요청',
#   'maxDigDepth': '11.24',
#   'no': '146'},
#  {'saupNo': '20180195',
#   'saupNm': '서울시 효제동 167외 1필지 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.00',
#   'no': '147'},
#  {'saupNo': '20180196',
#   'saupNm': '성남중1구역 도시환경정비사업 소규모지하안전영향평가',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.44',
#   'no': '148'},
#  {'saupNo': '20180197',
#   'saupNm': '국민은행 이태원지점 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.62',
#   'no': '149'},
#  {'saupNo': '20180198',
#   'saupNm': '국민은행 덕천동지점 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '30.39',
#   'no': '150'},
#  {'saupNo': '20180199',
#   'saupNm': '홍도동1구역 주택재건축정비사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '11.45',
#   'no': '151'},
#  {'saupNo': '20180200',
#   'saupNm': '아산시 배방지구 근린&오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.56',
#   'no': '152'},
#  {'saupNo': '20180201',
#   'saupNm': '죽전동 주거복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '17.60',
#   'no': '153'},
#  {'saupNo': '20180202',
#   'saupNm': '감삼동 파이오니아 주상복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.83',
#   'no': '154'},
#  {'saupNo': '20180203',
#   'saupNm': '과천지식정보타운 S6BL 공동주택 건설공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.11',
#   'no': '155'},
#  {'saupNo': '20180204',
#   'saupNm': '속초시 청학동 도시형생활주택',
#   'proStage': '보완요청',
#   'maxDigDepth': '16.60',
#   'no': '156'},
#  {'saupNo': '20180205',
#   'saupNm': '고촌읍 신곡리 532-124 번지 근린생활시설 및 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.60',
#   'no': '157'},
#  {'saupNo': '20180206',
#   'saupNm': '강릉 포남동 동도센트리움 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.58',
#   'no': '158'},
#  {'saupNo': '20180207',
#   'saupNm': '장미구역주택재건축정비사업조합',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.06',
#   'no': '159'},
#  {'saupNo': '20180208',
#   'saupNm': '롯데인재개발원 오산캠퍼스 리빌딩',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.80',
#   'no': '160'},
#  {'saupNo': '20180209',
#   'saupNm': '대구수성알파시티 비젼디엔씨(주) 지식산업센터 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.00',
#   'no': '161'},
#  {'saupNo': '20180210',
#   'saupNm': '창원중앙역세권 업무 1-4 000 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.31',
#   'no': '162'},
#  {'saupNo': '20180211',
#   'saupNm': '아산 배방읍 장재리 1717 복합시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.40',
#   'no': '163'},
#  {'saupNo': '20180212',
#   'saupNm': '성북동미술관 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.76',
#   'no': '164'},
#  {'saupNo': '20180213',
#   'saupNm': '덕진동 미르오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.80',
#   'no': '165'},
#  {'saupNo': '20180214',
#   'saupNm': '강남구 논현동 6-1 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.59',
#   'no': '166'},
#  {'saupNo': '20180215',
#   'saupNm': '양산시 북부동 00주거복합 신축공사',
#   'proStage': '평가서결재중',
#   'maxDigDepth': '19.85',
#   'no': '167'},
#  {'saupNo': '20180216',
#   'saupNm': '울산대 스마트오피스 신축 사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '16730.00',
#   'no': '168'},
#  {'saupNo': '20180217',
#   'saupNm': '평택 고덕택지지구 일상3-1-1 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.05',
#   'no': '169'},
#  {'saupNo': '20180218',
#   'saupNm': '진주시 칠암동 490-1 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '17.00',
#   'no': '170'},
#  {'saupNo': '20180219',
#   'saupNm': '진주시 칠암동 490-1 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '16.50',
#   'no': '171'},
#  {'saupNo': '20180220',
#   'saupNm': '진건 상업 4-1-1 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.55',
#   'no': '172'},
#  {'saupNo': '20180221',
#   'saupNm': '월계동 업무시설 및 근린생활시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '18.00',
#   'no': '173'},
#  {'saupNo': '20180222',
#   'saupNm': '진건 상업 3-4-1,2 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.31',
#   'no': '174'},
#  {'saupNo': '20180223',
#   'saupNm': '진건 상업 3-8-2 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.96',
#   'no': '175'},
#  {'saupNo': '20180224',
#   'saupNm': '속초시 조양동 1111-1 생활숙박시설 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '19.33',
#   'no': '176'},
#  {'saupNo': '20180225',
#   'saupNm': '제주 중문 복합리조트(숙박시설) 지하안전영향평가 (보완)',
#   'proStage': '제출완료',
#   'maxDigDepth': '2197.00',
#   'no': '177'},
#  {'saupNo': '20180226',
#   'saupNm': '석유화학단지 완충저류시설 설치사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.37',
#   'no': '178'},
#  {'saupNo': '20180227',
#   'saupNm': '서대구 산업단지 복합지식산업센터 사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.00',
#   'no': '179'},
#  {'saupNo': '20180228',
#   'saupNm': '대저1 자연재해위험개선지구 정비사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.00',
#   'no': '180'},
#  {'saupNo': '20180229',
#   'saupNm': '금포지구 우신미가뷰 1단지 공동주택 신축공사 소규모지하안전영향평가',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.00',
#   'no': '181'},
#  {'saupNo': '20180230',
#   'saupNm': '명지지구 상 17-1 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.40',
#   'no': '182'},
#  {'saupNo': '20180231',
#   'saupNm': '김천시 율곡동 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.15',
#   'no': '183'},
#  {'saupNo': '20180233',
#   'saupNm': '해운대구 중동 1270-1번지 외 8필지 업무시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.10',
#   'no': '184'},
#  {'saupNo': '20180234',
#   'saupNm': '김해 어방동 485-3번지외 퍼스트클래스오피스텔 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '1735.00',
#   'no': '185'},
#  {'saupNo': '20180235',
#   'saupNm': '판교 제2테크노밸리 E2-1블록 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '36.76',
#   'no': '186'},
#  {'saupNo': '20180236',
#   'saupNm': '의정부동 00주상복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.56',
#   'no': '187'},
#  {'saupNo': '20180237',
#   'saupNm': '동덕여자대학교 청담동 동신빌딩 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '17.36',
#   'no': '188'},
#  {'saupNo': '20180238',
#   'saupNm': '청담동 115-6외 4필지 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.56',
#   'no': '189'},
#  {'saupNo': '20180239',
#   'saupNm': '성본산업단지 공공폐수처리시설 설치공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '17.24',
#   'no': '190'},
#  {'saupNo': '20180240',
#   'saupNm': '김포시 고촌읍 성경침례교회 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.60',
#   'no': '191'},
#  {'saupNo': '20180241',
#   'saupNm': '역삼동 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.50',
#   'no': '192'},
#  {'saupNo': '20180242',
#   'saupNm': '남제주 복합화력 건설공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.40',
#   'no': '193'},
#  {'saupNo': '20180243',
#   'saupNm': '분당중앙교회 현황측량, 지반조사 및 소규모 지하안전영향평가용역',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.38',
#   'no': '194'},
#  {'saupNo': '20180244',
#   'saupNm': '여수시 웅천동 1876-1번지 일원 생활숙박시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.80',
#   'no': '195'},
#  {'saupNo': '20180247',
#   'saupNm': '강원도 강릉시 주문진 생활숙박시설 신축',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.61',
#   'no': '196'},
#  {'saupNo': '20180248',
#   'saupNm': '송파구 방이동 근생 및 업무시설(오피스텔) 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.74',
#   'no': '197'},
#  {'saupNo': '20180249',
#   'saupNm': '남원시 신정동 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '28.10',
#   'no': '198'},
#  {'saupNo': '20180250',
#   'saupNm': '울산 ktx역세권 코업시티호텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.04',
#   'no': '199'},
#  {'saupNo': '20180251',
#   'saupNm': '덕진동 오피스텔신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.90',
#   'no': '200'},
#  {'saupNo': '20180252',
#   'saupNm': '종광대2구역 주택재개발 정비사업 지하안전영향평가 용역',
#   'proStage': '승인요청',
#   'maxDigDepth': '32.48',
#   'no': '201'},
#  {'saupNo': '20180253',
#   'saupNm': '송도동 21-14,15,22,23번지 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.06',
#   'no': '202'},
#  {'saupNo': '20190001',
#   'saupNm': '서초동 1339-7번지 청화오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '33.45',
#   'no': '203'},
#  {'saupNo': '20190002',
#   'saupNm': '삼성동 20-5 근린생활시설 신축공사 소규모지하안전영향평가',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.71',
#   'no': '204'},
#  {'saupNo': '20190003',
#   'saupNm': '이태원동 181-20번지 외 근린생활시설 소규모지하안전영향평가',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.05',
#   'no': '205'},
#  {'saupNo': '20190004',
#   'saupNm': '서초구 방배동 백석대학교 서울캠퍼스 교육연구시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.00',
#   'no': '206'},
#  {'saupNo': '20190005',
#   'saupNm': '농성동 417-22외 7필지 주상복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '10.16',
#   'no': '207'},
#  {'saupNo': '20190006',
#   'saupNm': '천안시 서북구 불당동 1485번지 복합상업시설 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '16.30',
#   'no': '208'},
#  {'saupNo': '20190007',
#   'saupNm': '강남구 개포동 1238-5번지 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.00',
#   'no': '209'},
#  {'saupNo': '20190008',
#   'saupNm': 'S-OIL _2 SPM Construction Project',
#   'proStage': '보완요청',
#   'maxDigDepth': '15.76',
#   'no': '210'},
#  {'saupNo': '20190009',
#   'saupNm': '송파구 방이동 49-9 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '15.93',
#   'no': '211'},
#  {'saupNo': '20190010',
#   'saupNm': '이천 하이닉스 M16 비개착 공동구 설치공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '21.74',
#   'no': '212'},
#  {'saupNo': '20190011',
#   'saupNm': '고양시 덕양구 도내동 972, 973번지 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '20.70',
#   'no': '213'},
#  {'saupNo': '20190012',
#   'saupNm': '고양시 덕양구 도내동 974, 975번지 근린생활시설 및 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '20.70',
#   'no': '214'},
#  {'saupNo': '20190013',
#   'saupNm': '수성구 욱수동 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.30',
#   'no': '215'},
#  {'saupNo': '20190014',
#   'saupNm': '덕신디비홀딩스신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.64',
#   'no': '216'},
#  {'saupNo': '20190015',
#   'saupNm': '광주전남 빛그린 산업단지 공공폐수처리시설 소규모지하안전영향평가용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.30',
#   'no': '217'},
#  {'saupNo': '20190016',
#   'saupNm': '오설록 티뮤지엄 증축 개발사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '12.44',
#   'no': '218'},
#  {'saupNo': '20190017',
#   'saupNm': '군포첨단산업단지 내 지식산업센터 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.15',
#   'no': '219'},
#  {'saupNo': '20190018',
#   'saupNm': '연제구 연산동 00빌딩 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.95',
#   'no': '220'},
#  {'saupNo': '20190019',
#   'saupNm': '디센터1976지식산업센터 조성사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.00',
#   'no': '221'},
#  {'saupNo': '20190020',
#   'saupNm': '경기도 수원시 팔달구 고등동 300-16번지 외 근린생활시설',
#   'proStage': '승인요청',
#   'maxDigDepth': '18.04',
#   'no': '222'},
#  {'saupNo': '20190021',
#   'saupNm': '부천 문화예술회관 건립공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.00',
#   'no': '223'},
#  {'saupNo': '20190022',
#   'saupNm': '대구 달성군 현풍면 중리 오피스텔',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.30',
#   'no': '224'},
#  {'saupNo': '20190023',
#   'saupNm': '울산 남구 야음동(깨밭골) 지역주택조합아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.85',
#   'no': '225'},
#  {'saupNo': '20190024',
#   'saupNm': '충장배전스테이션 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '18.60',
#   'no': '226'},
#  {'saupNo': '20190025',
#   'saupNm': '미단시티 골든드래곤타워 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.96',
#   'no': '227'},
#  {'saupNo': '20190026',
#   'saupNm': '대구 남구 대명동 공공지원 민간임대주택(1단지) 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.48',
#   'no': '228'},
#  {'saupNo': '20190027',
#   'saupNm': '대구 남구 대명동 공공지원 민간임대주택(2단지) 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '18.14',
#   'no': '229'},
#  {'saupNo': '20190028',
#   'saupNm': '송파구 잠실동 183-12 주상복합',
#   'proStage': '제출완료',
#   'maxDigDepth': '20.00',
#   'no': '230'},
#  {'saupNo': '20190029',
#   'saupNm': '광주광역시 광산구 신가동 공동주택 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '14.80',
#   'no': '231'},
#  {'saupNo': '20190030',
#   'saupNm': '평택시 고덕 국제화계획지구 업무시설용지 12-2-1,2,3블럭 근린생활시설 및 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.28',
#   'no': '232'},
#  {'saupNo': '20190031',
#   'saupNm': '순천향대학교 부속 새병원 건립공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '29.68',
#   'no': '233'},
#  {'saupNo': '20190032',
#   'saupNm': '거제시 고현동 1100-3번지 복합시설 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '13.90',
#   'no': '234'},
#  {'saupNo': '20190033',
#   'saupNm': '가야동 3-11번지일원 주상복합신축공사',
#   'proStage': '평가서작성중',
#   'maxDigDepth': '18.60',
#   'no': '235'},
#  {'saupNo': '20190034',
#   'saupNm': '남산1구역 주택재건축 정비사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '12.25',
#   'no': '236'},
#  {'saupNo': '20190035',
#   'saupNm': '다사읍 매곡리 주거복합 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '12.31',
#   'no': '237'},
#  {'saupNo': '20190036',
#   'saupNm': '인천 검단신도시 AB-6BL 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '10.50',
#   'no': '238'},
#  {'saupNo': '20190037',
#   'saupNm': '봉명베리굿4차',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.60',
#   'no': '239'},
#  {'saupNo': '20190038',
#   'saupNm': '송산그린시티 폴리프라자 신축공사 소규모 지하안전영향평가용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.83',
#   'no': '240'},
#  {'saupNo': '20190039',
#   'saupNm': '송산그린시티 더드림프라자 신축공사 소규모 지하안전영향평가용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.43',
#   'no': '241'},
#  {'saupNo': '20190040',
#   'saupNm': '거제시 고현동 1100-3번지 복합시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '13.90',
#   'no': '242'},
#  {'saupNo': '20190041',
#   'saupNm': '김해 진영 택지개발지구 근린생활시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '16.85',
#   'no': '243'},
#  {'saupNo': '20190042',
#   'saupNm': '당진대덕수청지구 상업시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.33',
#   'no': '244'},
#  {'saupNo': '20190043',
#   'saupNm': '이천 비상저류조 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '24.10',
#   'no': '245'},
#  {'saupNo': '20190044',
#   'saupNm': '노원 외 2역 승강편의시설 설치공사 소규모 지하안전영향평가용역(노원역, 중계역)',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.17',
#   'no': '246'},
#  {'saupNo': '20190045',
#   'saupNm': '노원 외 2역 승강편의시설 설치공사 소규모 지하안전영향평가용역(군자역)',
#   'proStage': '제출완료',
#   'maxDigDepth': '11.70',
#   'no': '247'},
#  {'saupNo': '20190046',
#   'saupNm': '파주시- 명품3차 주상복합빌딩 신축공사 소규모지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.96',
#   'no': '248'},
#  {'saupNo': '20190047',
#   'saupNm': '서울중앙지사 복합시설 개발사업 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '32.10',
#   'no': '249'},
#  {'saupNo': '20190048',
#   'saupNm': '경북도청이전신도시 공공하수처리시설 설치사업(2단계)',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.30',
#   'no': '250'},
#  {'saupNo': '20190049',
#   'saupNm': '수성구 만촌동 아파트 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '17.95',
#   'no': '251'},
#  {'saupNo': '20190051',
#   'saupNm': '성수동 656-24번지 근린생활시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.10',
#   'no': '252'},
#  {'saupNo': '20190052',
#   'saupNm': '연경동 S-테라스 신축공사',
#   'proStage': '보완요청',
#   'maxDigDepth': '18.60',
#   'no': '253'},
#  {'saupNo': '20190053',
#   'saupNm': '서구 암남동 2-21일원 미진 이지비아 공동주택 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.30',
#   'no': '254'},
#  {'saupNo': '20190054',
#   'saupNm': '평택 고덕국제화계획지구 VIEW FIVE  신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '24.90',
#   'no': '255'},
#  {'saupNo': '20190055',
#   'saupNm': '안산시 시화 MTV 특별계획구역 C7-2 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.90',
#   'no': '256'},
#  {'saupNo': '20190056',
#   'saupNm': '상대원동 223-27번지 지식산업센터 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '19.31',
#   'no': '257'},
#  {'saupNo': '20190057',
#   'saupNm': '동구 복합문화체육센터 건립',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.86',
#   'no': '258'},
#  {'saupNo': '20190058',
#   'saupNm': '부산광역시 문현3구역 주택재개발 정비사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '20.75',
#   'no': '259'},
#  {'saupNo': '20190059',
#   'saupNm': '천안시 서북구 업성동 자동차전시장 신축공사',
#   'proStage': '검토 및 현지조사 의뢰',
#   'maxDigDepth': '13.66',
#   'no': '260'},
#  {'saupNo': '20190060',
#   'saupNm': '서초동 1327-34 복합시설 신축공사 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '29.52',
#   'no': '261'},
#  {'saupNo': '20190061',
#   'saupNm': '성남시 수정구 태평동 엘리시아 오피스텔',
#   'proStage': '협의요청',
#   'maxDigDepth': '14.28',
#   'no': '262'},
#  {'saupNo': '20190062',
#   'saupNm': '광주 동구 수기동 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.68',
#   'no': '263'},
#  {'saupNo': '20190064',
#   'saupNm': '경기도 김포시 양촌읍 양곡리 405-4외 4필지 업무시설 및 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.00',
#   'no': '264'},
#  {'saupNo': '20190065',
#   'saupNm': '유성광역복합환승센터 개발사업 부지 내 복합여객터미널 사업 지하안전영향평가서',
#   'proStage': '제출완료',
#   'maxDigDepth': '39.90',
#   'no': '265'},
#  {'saupNo': '20190066',
#   'saupNm': '도시철도 환기구(감전~주례) 이설공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '11.00',
#   'no': '266'},
#  {'saupNo': '20190067',
#   'saupNm': '범일3-1 도시환경정비사업',
#   'proStage': '승인요청',
#   'maxDigDepth': '19.80',
#   'no': '267'},
#  {'saupNo': '20190068',
#   'saupNm': '한국국제전시장 지구단위계획구역(E2-2) 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.95',
#   'no': '268'},
#  {'saupNo': '20190069',
#   'saupNm': 'CGV 울산 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.39',
#   'no': '269'},
#  {'saupNo': '20190070',
#   'saupNm': '춘천시 근화동 센트럴 파크 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.40',
#   'no': '270'},
#  {'saupNo': '20190071',
#   'saupNm': '춘천시 조양동 레지던스 호텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.10',
#   'no': '271'},
#  {'saupNo': '20190072',
#   'saupNm': '춘천시 근화1지역주택조합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.83',
#   'no': '272'},
#  {'saupNo': '20190073',
#   'saupNm': '메리츠화재 봉래동사옥 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.20',
#   'no': '273'},
#  {'saupNo': '20190074',
#   'saupNm': '울산광역시 중구 우정동 복합시설 신축설계',
#   'proStage': '평가서반려',
#   'maxDigDepth': '19.00',
#   'no': '274'},
#  {'saupNo': '20190075',
#   'saupNm': '식사구역 E9-7,8 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.31',
#   'no': '275'},
#  {'saupNo': '20190076',
#   'saupNm': '옥정동 965-6 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.77',
#   'no': '276'},
#  {'saupNo': '20190077',
#   'saupNm': '파주시 와동동 1469-1 근린생활시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.95',
#   'no': '277'},
#  {'saupNo': '20190078',
#   'saupNm': '강남구 역삼동 825-27번지 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.19',
#   'no': '278'},
#  {'saupNo': '20190079',
#   'saupNm': '원릉역 00플라자1 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.36',
#   'no': '279'},
#  {'saupNo': '20190080',
#   'saupNm': '판교 제2테크노밸리 E2-1블록 신축공사(보완)',
#   'proStage': '제출완료',
#   'maxDigDepth': '35.11',
#   'no': '280'},
#  {'saupNo': '20190081',
#   'saupNm': '논현동 238-2 모두렌탈 사옥 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.58',
#   'no': '281'},
#  {'saupNo': '20190082',
#   'saupNm': '대전보건대학교 치의학센터 및 학술정보관 증축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.00',
#   'no': '282'},
#  {'saupNo': '20190083',
#   'saupNm': '가산동 더리브 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.47',
#   'no': '283'},
#  {'saupNo': '20190084',
#   'saupNm': '송촌동 상점가 공용주차 전용빌딩 건립공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.50',
#   'no': '284'},
#  {'saupNo': '20190085',
#   'saupNm': '신림동 역세권 2030 청년주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.01',
#   'no': '285'},
#  {'saupNo': '20190086',
#   'saupNm': '광주광역시 화정동 일원 주상복합 계획안(1BL)',
#   'proStage': '승인요청',
#   'maxDigDepth': '16.95',
#   'no': '286'},
#  {'saupNo': '20190087',
#   'saupNm': '광주광역시 화정동 일원 주상복합 계획안(2BL)',
#   'proStage': '승인요청',
#   'maxDigDepth': '16.47',
#   'no': '287'},
#  {'saupNo': '20190088',
#   'saupNm': '가산동 더리브 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.47',
#   'no': '288'},
#  {'saupNo': '20190089',
#   'saupNm': '정자동 4-5번지 연구시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '37.50',
#   'no': '289'},
#  {'saupNo': '20190090',
#   'saupNm': '강남구 역삼동 825-27번지 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.19',
#   'no': '290'},
#  {'saupNo': '20190091',
#   'saupNm': '일광면 일광지구 E6B-2,3L 골드타워 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.20',
#   'no': '291'},
#  {'saupNo': '20190092',
#   'saupNm': '남정지구 우수저류시설설치사업',
#   'proStage': '협의요청',
#   'maxDigDepth': '15.00',
#   'no': '292'},
#  {'saupNo': '20190093',
#   'saupNm': '서둔동 16롯트(6-1-2블럭) 근생 및 생활 숙박시설 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '19.00',
#   'no': '293'},
#  {'saupNo': '20190094',
#   'saupNm': '낙동강권역부문 사옥 건립사업',
#   'proStage': '보완요청',
#   'maxDigDepth': '19.00',
#   'no': '294'},
#  {'saupNo': '20190095',
#   'saupNm': '광산구 첨단지구 쌍암동 오피스텔 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.00',
#   'no': '295'},
#  {'saupNo': '20190100',
#   'saupNm': '대구 감삼동 주거복합 신축공사 소규모지하안전영향평가',
#   'proStage': '정보수정중',
#   'maxDigDepth': '19.26',
#   'no': '296'},
#  {'saupNo': '20190101',
#   'saupNm': '창원시 상남동 7-2 00빌딩 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.62',
#   'no': '297'},
#  {'saupNo': '20190102',
#   'saupNm': '동아 D TOWN 개발사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.72',
#   'no': '298'},
#  {'saupNo': '20190103',
#   'saupNm': '대교IT 지식산업센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.00',
#   'no': '299'},
#  {'saupNo': '20190104',
#   'saupNm': '부산도시철도(8차) 1,2호선 역사 시설개량공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.28',
#   'no': '300'},
#  {'saupNo': '20190105',
#   'saupNm': '345kV신성남~동서울T/L 판교대장지구 지중화공사 지질조사, 지하안전영향평가 용역',
#   'proStage': '협의요청',
#   'maxDigDepth': '51.00',
#   'no': '301'},
#  {'saupNo': '20190106',
#   'saupNm': '울산 중구 우정동 주거복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.56',
#   'no': '302'},
#  {'saupNo': '20190107',
#   'saupNm': '제주 LIFE GARDEN(프로젝트 ECO) 웰컴센터',
#   'proStage': '승인요청',
#   'maxDigDepth': '14.86',
#   'no': '303'},
#  {'saupNo': '20190108',
#   'saupNm': '성남글로벌 ICT융합 플래닛',
#   'proStage': '협의요청',
#   'maxDigDepth': '21.66',
#   'no': '304'},
#  {'saupNo': '20190109',
#   'saupNm': '오설록 티뮤지엄 증축 개발사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.44',
#   'no': '305'},
#  {'saupNo': '20190110',
#   'saupNm': '남양뉴타운 근린생활시설 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '16.58',
#   'no': '306'},
#  {'saupNo': '20190111',
#   'saupNm': '동부산 오시리아 타워레지던스 신축공사',
#   'proStage': '승인요청',
#   'maxDigDepth': '12.40',
#   'no': '307'},
#  {'saupNo': '20190112',
#   'saupNm': '의왕테크노파크 복합시설 신축공사',
#   'proStage': '협의요청',
#   'maxDigDepth': '18.06',
#   'no': '308'},
#  {'saupNo': '20190113',
#   'saupNm': '양주 옥정 유일스카이오피스텔',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.00',
#   'no': '309'},
#  {'saupNo': '20190114',
#   'saupNm': '판교 제2테크노밸리 도심첨단산업단지',
#   'proStage': '협의요청',
# ...
#   'maxDigDepth': '13.03',
#   'no': '875'},
#  {'saupNo': '20200357',
#   'saupNm': '고양 덕은 도시개발사업지구 업무 11,12블럭 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '29.46',
#   'no': '876'},
#  {'saupNo': '20200358',
#   'saupNm': '광양(1)공업용수도 노후관 개량사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.06',
#   'no': '877'},
#  {'saupNo': '20200359',
#   'saupNm': '홍성 고암리 임대아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.15',
#   'no': '878'},
#  {'saupNo': '20200360',
#   'saupNm': '내당동 00아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '10.50',
#   'no': '879'},
#  {'saupNo': '20200362',
#   'saupNm': '횡성군 읍하리 191-1 주상복합신축공사 ',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.00',
#   'no': '880'},
#  {'saupNo': '20200363',
#   'saupNm': '오창읍 공동주택 및 체육시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.00',
#   'no': '881'},
#  {'saupNo': '20200364',
#   'saupNm': '정산농공단지 완충저류시설 설치사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.20',
#   'no': '882'},
#  {'saupNo': '20200365',
#   'saupNm': '청주시 제2매립장 조성사업 소규모 지하안전영향평가',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '19.20',
#   'no': '883'},
#  {'saupNo': '20200366',
#   'saupNm': '불당동 1537-2번지 소규모지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.20',
#   'no': '884'},
#  {'saupNo': '20200368',
#   'saupNm': '불당동 1537-2번지 소규모지하안전영향평가',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '19.20',
#   'no': '885'},
#  {'saupNo': '20200369',
#   'saupNm': '역삼동 653-4번지 지구단위계획구역 A1BL 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '32.98',
#   'no': '886'},
#  {'saupNo': '20200370',
#   'saupNm': '충남 아산시 신창면 모아엘가아파트 2단지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '11.91',
#   'no': '887'},
#  {'saupNo': '20200371',
#   'saupNm': '대전시 동구 성남동 1구역 주택재개발',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.92',
#   'no': '888'},
#  {'saupNo': '20200372',
#   'saupNm': '광양지역 전기공급시설 전력구공사(백운-광양항 2차)',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.10',
#   'no': '889'},
#  {'saupNo': '20200373',
#   'saupNm': '대구 달성공원역 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.10',
#   'no': '890'},
#  {'saupNo': '20200374',
#   'saupNm': '속초시 영랑동 생활숙박시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.90',
#   'no': '891'},
#  {'saupNo': '20200375',
#   'saupNm': '용인시 처인구 역북동 504-13번지 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.15',
#   'no': '892'},
#  {'saupNo': '20200377',
#   'saupNm': '석관동 173-1번지 화랑 청년주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.31',
#   'no': '893'},
#  {'saupNo': '20200378',
#   'saupNm': '경기도 이천시 창전동 일반업무시설 및 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.59',
#   'no': '894'},
#  {'saupNo': '20200379',
#   'saupNm': '대전광역시 중구 대흥동 456번지 근린생활시설 및 도시형생활주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.50',
#   'no': '895'},
#  {'saupNo': '20200380',
#   'saupNm': '성북구 하월곡동 역세권 청년주택 소규모 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.80',
#   'no': '896'},
#  {'saupNo': '20200381',
#   'saupNm': '강북구 수유동 역세권 청년주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.70',
#   'no': '897'},
#  {'saupNo': '20200382',
#   'saupNm': '인천지역 전기공급시설 전력구공사(동송도S/S~서송도S/S)',
#   'proStage': '제출완료',
#   'maxDigDepth': '75.00',
#   'no': '898'},
#  {'saupNo': '20200383',
#   'saupNm': '서울시 강남구 논현동 29-8번지 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.30',
#   'no': '899'},
#  {'saupNo': '20200384',
#   'saupNm': '광진구 화양동 116-1 일대 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.46',
#   'no': '900'},
#  {'saupNo': '20200385',
#   'saupNm': '영등포 3가 5-10 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.96',
#   'no': '901'},
#  {'saupNo': '20200386',
#   'saupNm': '청주시 서원구 남이면 물류센터 1B-1BL 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '30.31',
#   'no': '902'},
#  {'saupNo': '20200387',
#   'saupNm': '동탄~인덕원 복선전철 제9공구 건설공사 ',
#   'proStage': '제출완료',
#   'maxDigDepth': '46.00',
#   'no': '903'},
#  {'saupNo': '20200388',
#   'saupNm': '서울시 강남구 논현동 29-16번지 근린생활시설 신축공사',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '13.60',
#   'no': '904'},
#  {'saupNo': '20200389',
#   'saupNm': '수원 덕산병원 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '23.51',
#   'no': '905'},
#  {'saupNo': '20200390',
#   'saupNm': '대전유성 구암드림타운 건설사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.40',
#   'no': '906'},
#  {'saupNo': '20200391',
#   'saupNm': '천안하수처리장 현대화사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.00',
#   'no': '907'},
#  {'saupNo': '20200392',
#   'saupNm': '광주지역 전기공급시설 전력구공사(신광주~일곡 지중화)지하안전영향평가 용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '33.28',
#   'no': '908'},
#  {'saupNo': '20200393',
#   'saupNm': '서울시 강남구 신사동 546-6번지 외 2근린생활시설 신축',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.41',
#   'no': '909'},
#  {'saupNo': '20200395',
#   'saupNm': '계룡 펠리피아 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.40',
#   'no': '910'},
#  {'saupNo': '20200396',
#   'saupNm': '불당동 1534-1 근린생활시설 및 업무시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.68',
#   'no': '911'},
#  {'saupNo': '20200397',
#   'saupNm': '부천시 심곡동 오피스텔  신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.22',
#   'no': '912'},
#  {'saupNo': '20200398',
#   'saupNm': '한전 KDN 서울지역본부 사옥신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '22.70',
#   'no': '913'},
#  {'saupNo': '20200399',
#   'saupNm': '운서동3089번지 주차전용 건축물 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.61',
#   'no': '914'},
#  {'saupNo': '20200400',
#   'saupNm': '태평아파트 재건축 정비사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.65',
#   'no': '915'},
#  {'saupNo': '20200401',
#   'saupNm': '부전동 디알시티 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.41',
#   'no': '916'},
#  {'saupNo': '20200404',
#   'saupNm': '태평종합사회복지관 건립공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.06',
#   'no': '917'},
#  {'saupNo': '20200405',
#   'saupNm': '서울시 역삼동 826번지 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.00',
#   'no': '918'},
#  {'saupNo': '20200406',
#   'saupNm': '원주시 관설동 1426번지 공동주택',
#   'proStage': '제출완료',
#   'maxDigDepth': '10.55',
#   'no': '919'},
#  {'saupNo': '20200407',
#   'saupNm': '광주광역시 서구 광천동 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.50',
#   'no': '920'},
#  {'saupNo': '20200408',
#   'saupNm': '안양시 만안구 안양동 627-1,2,3번지 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.57',
#   'no': '921'},
#  {'saupNo': '20200409',
#   'saupNm': '양산~사송연계 2단계 및 사송지구 내 열수송관공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '7.60',
#   'no': '922'},
#  {'saupNo': '20200410',
#   'saupNm': '안양시 호계동 959-1번지 일대 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.66',
#   'no': '923'},
#  {'saupNo': '20200411',
#   'saupNm': '아산 모종동 562-1외 1 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '32.96',
#   'no': '924'},
#  {'saupNo': '20200412',
#   'saupNm': '달방댐 침투량 측정시설 설치공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '11.19',
#   'no': '925'},
#  {'saupNo': '20200413',
#   'saupNm': '화성지역 전기공급시설 전력구 공사(중동탄 분기)',
#   'proStage': '제출완료',
#   'maxDigDepth': '33.31',
#   'no': '926'},
#  {'saupNo': '20200414',
#   'saupNm': '서울시 상봉동 역세권 청년주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.96',
#   'no': '927'},
#  {'saupNo': '20200415',
#   'saupNm': '강동구 강일동 723 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.68',
#   'no': '928'},
#  {'saupNo': '20200416',
#   'saupNm': '대전광역시 중구 선화동 주거복합신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.02',
#   'no': '929'},
#  {'saupNo': '20200417',
#   'saupNm': '안양시 만안구 안양동 627-30,32번지 업무복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '31.24',
#   'no': '930'},
#  {'saupNo': '20200418',
#   'saupNm': '시흥장현지구 일반상업용지 22블럭 근린생활시설 신축공사 소규모 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.39',
#   'no': '931'},
#  {'saupNo': '20200419',
#   'saupNm': '부천 세종병원 증축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.17',
#   'no': '932'},
#  {'saupNo': '20200420',
#   'saupNm': '당진 수청지구 도시개발사업 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.40',
#   'no': '933'},
#  {'saupNo': '20200421',
#   'saupNm': '행정중심복합도시 6-3생활권 H3BL 주상복합 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '16.21',
#   'no': '934'},
#  {'saupNo': '20200422',
#   'saupNm': '삼성전자(주) 평택캠퍼스 전력구 인입공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.70',
#   'no': '935'},
#  {'saupNo': '20200423',
#   'saupNm': '수원-화성지역 전기공급시설 전력구공사(호매실-남수원)\t',
#   'proStage': '제출완료',
#   'maxDigDepth': '60.20',
#   'no': '936'},
#  {'saupNo': '20200424',
#   'saupNm': '부천시 춘의동 204-4,6번지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.95',
#   'no': '937'},
#  {'saupNo': '20200425',
#   'saupNm': '봉명 베리굿2차 주상복합 신축공사 소규모지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.19',
#   'no': '938'},
#  {'saupNo': '20200426',
#   'saupNm': '속초 조양동 시리우스 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.79',
#   'no': '939'},
#  {'saupNo': '20200427',
#   'saupNm': '대구 삼덕동 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.65',
#   'no': '940'},
#  {'saupNo': '20200428',
#   'saupNm': '덕이지구 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.90',
#   'no': '941'},
#  {'saupNo': '20200429',
#   'saupNm': '중구 순화 1-2지구 도시환경정비사업 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.36',
#   'no': '942'},
#  {'saupNo': '20200430',
#   'saupNm': '시흥은계지구 상업2-1 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.03',
#   'no': '943'},
#  {'saupNo': '20200432',
#   'saupNm': '응암동 OO주상복합 신축공사 중 소규모지하안전영향평가',
#   'proStage': '정보수정중',
#   'maxDigDepth': '17.04',
#   'no': '944'},
#  {'saupNo': '20200433',
#   'saupNm': '수성32구역 주택재개발정비사업 소규모지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.97',
#   'no': '945'},
#  {'saupNo': '20200434',
#   'saupNm': '중구 남산동2가 6-1번지 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.55',
#   'no': '946'},
#  {'saupNo': '20200435',
#   'saupNm': '판교창조 경제밸리 사업지원시설용지 D4-2 오피스텔 신축공사 ',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.65',
#   'no': '947'},
#  {'saupNo': '20200436',
#   'saupNm': '대구 신암동 데시앙 아파트 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '10.25',
#   'no': '948'},
#  {'saupNo': '20200437',
#   'saupNm': '연산동 한진빌딩 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '17.30',
#   'no': '949'},
#  {'saupNo': '20200438',
#   'saupNm': '심곡본동 776-2외 8필지 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.95',
#   'no': '950'},
#  {'saupNo': '20200439',
#   'saupNm': '서울특별시 영등포구 당산동6가 복합시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.93',
#   'no': '951'},
#  {'saupNo': '20200440',
#   'saupNm': '이천시 부발읍 죽당리 59-1번지일원 물류센터 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.40',
#   'no': '952'},
#  {'saupNo': '20200441',
#   'saupNm': '용인 영덕 기업형 임대주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.16',
#   'no': '953'},
#  {'saupNo': '20200442',
#   'saupNm': '오포 공공하수처리시설 증설사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.83',
#   'no': '954'},
#  {'saupNo': '20200443',
#   'saupNm': '새연산아파트 소규모재건축정비사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.55',
#   'no': '955'},
#  {'saupNo': '20200444',
#   'saupNm': '운정지구 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.60',
#   'no': '956'},
#  {'saupNo': '20200445',
#   'saupNm': '강남구 논현동 118-13번지 삼아빌딩 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.43',
#   'no': '957'},
#  {'saupNo': '20200446',
#   'saupNm': ' 광안동 199-7 도시형생활주택(주상복합) 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.80',
#   'no': '958'},
#  {'saupNo': '20200448',
#   'saupNm': '충무로 남산 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '6206.08',
#   'no': '959'},
#  {'saupNo': '20200449',
#   'saupNm': '율촌~덕례 주배관 건설공사 ',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.31',
#   'no': '960'},
#  {'saupNo': '20200451',
#   'saupNm': '도곡동 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.55',
#   'no': '961'},
#  {'saupNo': '20200452',
#   'saupNm': '인천시 미추홀구 용현동 624-47, 48 오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.85',
#   'no': '962'},
#  {'saupNo': '20200453',
#   'saupNm': '강남역 오피스 개발사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '30.67',
#   'no': '963'},
#  {'saupNo': '20200454',
#   'saupNm': '관양동 1504-9 외 1필지 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.70',
#   'no': '964'},
#  {'saupNo': '20200455',
#   'saupNm': '검단신도시 오수중계펌프장 및 관로 공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '13.05',
#   'no': '965'},
#  {'saupNo': '20200456',
#   'saupNm': '서울 어울림 체육센터 건립',
#   'proStage': '사업 등록 완료',
#   'maxDigDepth': '18.15',
#   'no': '966'},
#  {'saupNo': '20200457',
#   'saupNm': '행정중심복합도시 6-3생활권 H2 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.57',
#   'no': '967'},
#  {'saupNo': '20200458',
#   'saupNm': '고양시 지축공공주택지구 C1-2-1 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.49',
#   'no': '968'},
#  {'saupNo': '20200459',
#   'saupNm': '원주 무실동 1721-4번지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.96',
#   'no': '969'},
#  {'saupNo': '20200460',
#   'saupNm': '야음제1지구 가로주택정비사업 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '18.10',
#   'no': '970'},
#  {'saupNo': '20200461',
#   'saupNm': '서울시립대학교 미래융합관 건립공사 소규모 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.00',
#   'no': '971'},
#  {'saupNo': '20200462',
#   'saupNm': '만촌네거리 주거복합 신축공사 지하안전영향평가',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.95',
#   'no': '972'},
#  {'saupNo': '20200463',
#   'saupNm': '대구광역시 달서구 본동 743번지 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '27.27',
#   'no': '973'},
#  {'saupNo': '20200464',
#   'saupNm': '여수시 미평동 해광샹그릴라 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.65',
#   'no': '974'},
#  {'saupNo': '20200465',
#   'saupNm': '분당선 미금역외 5개역 승강설비설치공사 실시설계용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '12.29',
#   'no': '975'},
#  {'saupNo': '20200466',
#   'saupNm': '신안산선 복선전철 민간투자사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '35.00',
#   'no': '976'},
#  {'saupNo': '20200467',
#   'saupNm': '정부과천청사역 승강설비 설치공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.96',
#   'no': '977'},
#  {'saupNo': '20200468',
#   'saupNm': '분당선 미금역외 5개역 승강설비설치공사 실시설계용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '14.55',
#   'no': '978'},
#  {'saupNo': '20200469',
#   'saupNm': '서초동 생활형숙박시설 2차 1591-8번지 일대 신축사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.26',
#   'no': '979'},
#  {'saupNo': '20200470',
#   'saupNm': '수원시 서둔동 17-8번지 일대 역세권1구역 2-1블럭 외 8개블럭 신축공사(4-1,2BL)',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.96',
#   'no': '980'},
#  {'saupNo': '20200471',
#   'saupNm': '강남구 역삼동 근린생활시설 및 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.78',
#   'no': '981'},
#  {'saupNo': '20200472',
#   'saupNm': '삼성동 144-6 오피스텔 신축공사',
#   'proStage': '정보수정중',
#   'maxDigDepth': '30.02',
#   'no': '982'},
#  {'saupNo': '20200473',
#   'saupNm': '운남동 영종하늘도시 00오피스텔 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.03',
#   'no': '983'},
#  {'saupNo': '20200474',
#   'saupNm': '인천도시철도 1호선 검단연장선 건설공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '29.40',
#   'no': '984'},
#  {'saupNo': '20200475',
#   'saupNm': '운니동 사옥 블루캣츠 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.06',
#   'no': '985'},
#  {'saupNo': '20200476',
#   'saupNm': '진동물재생센터 증설사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.05',
#   'no': '986'},
#  {'saupNo': '20200477',
#   'saupNm': '고덕비즈밸리 자족 2-3 00사옥 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '25.70',
#   'no': '987'},
#  {'saupNo': '20200478',
#   'saupNm': '대구 동구 신천동 주거복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '23.34',
#   'no': '988'},
#  {'saupNo': '20200479',
#   'saupNm': '음성-진천지역 전기공급시설 전력구공사(광혜원-대소)',
#   'proStage': '제출완료',
#   'maxDigDepth': '34.67',
#   'no': '989'},
#  {'saupNo': '20200480',
#   'saupNm': '서울 중구 필동3가 78-8외2필지 근린생활시설 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '24.39',
#   'no': '990'},
#  {'saupNo': '20200481',
#   'saupNm': '고양시 덕양구 벽제동 523-24번지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '16.06',
#   'no': '991'},
#  {'saupNo': '20200483',
#   'saupNm': '효목동 00아파트 신축에 따른 소규모지하안전영향평가 용역',
#   'proStage': '제출완료',
#   'maxDigDepth': '18.81',
#   'no': '992'},
#  {'saupNo': '20200484',
#   'saupNm': '제기6구역 주택재개발정비조합',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.25',
#   'no': '993'},
#  {'saupNo': '20200485',
#   'saupNm': '인천 용현·학익 1블록 도시개발구역 주거복합 신축공사[업무2]',
#   'proStage': '제출완료',
#   'maxDigDepth': '13.87',
#   'no': '994'},
#  {'saupNo': '20200486',
#   'saupNm': '성수동2가 277-103 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.24',
#   'no': '995'},
#  {'saupNo': '20200487',
#   'saupNm': '창원 중앙역세권 업무1-6 협성루에나 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '15.30',
#   'no': '996'},
#  {'saupNo': '20200488',
#   'saupNm': '수원발KTX직결사업',
#   'proStage': '제출완료',
#   'maxDigDepth': '21.79',
#   'no': '997'},
#  {'saupNo': '20200489',
#   'saupNm': '울산 무거동 공동주택 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.61',
#   'no': '998'},
#  {'saupNo': '20200490',
#   'saupNm': '강남구 논현동 249-9번지 외 1필지 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '26.26',
#   'no': '999'},
#  {'saupNo': '20200491',
#   'saupNm': '화성동탄2 C-2BL 주상복합 신축공사',
#   'proStage': '제출완료',
#   'maxDigDepth': '19.88',
#   'no': '1000'},
#  ...]

# %% [markdown]
# ## 리스트에서 정보 변환

# %% [markdown]
# - 위에거는 전체 실행만

# %%
import os
import json
from tqdm import tqdm
from typing import List, Dict

# NDJSON 저장 함수 (중복 방지 포함)
def append_ndjson(data_list: List[Dict], file_path: str, key_name: str = None):
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    existing_ids = set()
    if os.path.exists(file_path) and key_name:
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line.strip())
                    if key_name in obj:
                        existing_ids.add(obj[key_name])
                except json.JSONDecodeError:
                    continue

    new_count = 0
    with open(file_path, "a", encoding="utf-8") as f:
        for item in data_list:
            if key_name:
                item_id = item.get(key_name)
                if item_id in existing_ids:
                    continue
                existing_ids.add(item_id)
            f.write(json.dumps(item, ensure_ascii=False) + "\n")
            new_count += 1

    # print(f"✅ {new_count}개 항목이 {file_path}에 추가되었습니다.")
    return new_count

# 함수 이름과 key 매핑
info_api_mapping = {
    "지하안전평가_리스트": {
        "key": "evalNo",
        "func": get_impat_evaluation_info
    },
    "소규모지하안전평가_리스트": {
        "key": "evalNo",
        "func": get_small_impat_evaluation_info
    },
    "착공후지하안전조사_리스트": {
        "key": "evalNo",
        "func": get_post_construction_check_info
    },
    "안전점검대상_지하시설물_리스트": {
        "key": "facilNo",
        "func": get_underground_facility_info
    },
    "지반침하위험도평가_리스트": {
        "key": "evalNo",
        "func": get_risk_safety_info
    },
    "지반침하사고_리스트": {
        "key": "sagoNo",
        "func": get_subsidence_accident_info
    },
    "전문기관_리스트": {
        "key": "corpCd",
        "func": get_agency_info
    },
    "지하개발사업_리스트": {
        "key": "saupNo",
        "func": get_underground_project_info
    }
}

# 메인 실행 루프
list_base_path = "Database/openapi"
list_files = [f for f in os.listdir(list_base_path) if f.endswith("_전체.json")]

for file in list_files:
    file_path = os.path.join(list_base_path, file)
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    label = file.replace("_전체.json", "")
    mapping = info_api_mapping.get(label)

    if not mapping:
        print(f"❌ 처리 불가능한 리스트: {label}")
        continue

    key_name = mapping["key"]
    info_func = mapping["func"]
    output_path = f"Database/openapi/{label.replace('리스트', '정보')}.ndjson"

    print(f"🔍 [{label}] → {info_func.__name__} 호출 중...")
    for item in tqdm(data):
        id_value = item.get(key_name)
        if id_value:
            result = info_func(id_value)
            if isinstance(result, dict):
                append_ndjson([result], output_path, key_name=key_name)
# Out:
# 🔍 [지하안전평가_리스트] → get_impat_evaluation_info 호출 중...
# 100%|██████████| 2607/2607 [07:57<00:00,  5.46it/s]
# 🔍 [안전점검대상_지하시설물_리스트] → get_underground_facility_info 호출 중...
# 100%|██████████| 700/700 [02:30<00:00,  4.64it/s]
# 🔍 [착공후지하안전조사_리스트] → get_post_construction_check_info 호출 중...
# 100%|██████████| 1059/1059 [03:16<00:00,  5.38it/s]
# 🔍 [전문기관_리스트] → get_agency_info 호출 중...
# 100%|██████████| 394/394 [01:22<00:00,  4.76it/s]
# 🔍 [소규모지하안전평가_리스트] → get_small_impat_evaluation_info 호출 중...
# 100%|██████████| 5232/5232 [14:54<00:00,  5.85it/s]
# ❌ 처리 불가능한 리스트: 지하시설물_리스트
# 🔍 [지하개발사업_리스트] → get_underground_project_info 호출 중...
# 100%|██████████| 7594/7594 [21:43<00:00,  5.83it/s]
# ❌ 처리 불가능한 리스트: 중점관리대상_리스트
# 🔍 [지반침하사고_리스트] → get_subsidence_accident_info 호출 중...
# 100%|██████████| 1451/1451 [03:58<00:00,  6.08it/s]
# 🔍 [지반침하위험도평가_리스트] → get_risk_safety_info 호출 중...
# 100%|██████████| 10/10 [00:01<00:00,  7.74it/s]

# %% [markdown]
# - 지정 실행 가능

# %%
import os
import json
from tqdm import tqdm
from typing import List, Dict, Optional

def append_ndjson(data_list: List[Dict], file_path: str, key_name: Optional[str] = None):
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    existing_ids = set()

    if os.path.exists(file_path) and key_name:
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line.strip())
                    if key_name in obj:
                        existing_ids.add(obj[key_name])
                except json.JSONDecodeError:
                    continue

    new_count = 0
    with open(file_path, "a", encoding="utf-8") as f:
        for item in data_list:
            if key_name:
                item_id = item.get(key_name)
                if item_id in existing_ids:
                    continue
                existing_ids.add(item_id)
            f.write(json.dumps(item, ensure_ascii=False) + "\n")
            new_count += 1

    return new_count


# 🔁 리스트 ↔ 정보 매핑 (list_from 추가됨)
info_api_mapping = {
    "지하안전평가_정보": {
        "key": "evalNo",
        "func": get_impat_evaluation_info,
        "list_from": "지하안전평가_리스트"
    },
    "소규모지하안전평가_정보": {
        "key": "evalNo",
        "func": get_small_impat_evaluation_info,
        "list_from": "소규모지하안전평가_리스트"
    },
    "착공후지하안전조사_정보": {
        "key": "evalNo",
        "func": get_post_construction_check_info,
        "list_from": "착공후지하안전조사_리스트"
    },
    "안전점검대상_지하시설물_정보": {
        "key": "facilNo",
        "func": get_underground_facility_info,
        "list_from": "안전점검대상_지하시설물_리스트"
    },
    "안전점검대상_지하시설물_점검결과": {
        "key": "facilNo",
        "func": get_underground_facility_result,
        "list_from": "안전점검대상_지하시설물_리스트"
    },
    "지반침하사고_정보": {
        "key": "sagoNo",
        "func": get_subsidence_accident_info,
        "list_from": "지반침하사고_리스트"
    },
    "전문기관_정보": {
        "key": "corpCd",
        "func": get_agency_info,
        "list_from": "전문기관_리스트"
    },
    "전문기관_실적": {
        "key": "corpCd",
        "func": get_agency_results,
        "list_from": "전문기관_리스트"
    },
    "지하개발사업_정보": {
        "key": "saupNo",
        "func": get_underground_project_info,
        "list_from": "지하개발사업_리스트"
    },
    "지반침하_안전조치내용": { # 안 줌
        "key": "evalNo",
        "func": get_risk_safety_info,
        "list_from": "지반침하위험도평가_리스트"
    },
    "지반침하_응급조치내용": { # 안 줌
        "key": "evalNo",
        "func": get_risk_emergency_info,
        "list_from": "지반침하위험도평가_리스트"
    },
    "중점관리대상_정보": { # 안 줌
        "key": "facilNo",
        "func": get_priority_control_info,
        "list_from": "중점관리대상_리스트"
    }
}


# ✅ 확장된 실행 함수 (리스트 공유 처리 포함)
def run_info_scraper(list_base_path: str = "Database/openapi", target_labels: Optional[List[str]] = None):
    # 1. 필요한 리스트만 한 번씩 불러옴
    shared_lists: Dict[str, List[Dict]] = {}
    for mapping in info_api_mapping.values():
        list_label = mapping["list_from"]
        if list_label not in shared_lists:
            file_path = os.path.join(list_base_path, f"{list_label}_전체.json")
            if os.path.exists(file_path):
                with open(file_path, "r", encoding="utf-8") as f:
                    shared_lists[list_label] = json.load(f)
            else:
                print(f"❌ 리스트 파일 없음: {list_label}_전체.json")
                shared_lists[list_label] = []

    # 2. 지정된 label만 처리
    for label, mapping in info_api_mapping.items():
        if target_labels and label not in target_labels:
            continue

        list_label = mapping["list_from"]
        data = shared_lists.get(list_label, [])
        key_name = mapping["key"]
        info_func = mapping["func"]
        output_path = os.path.join(list_base_path, f"{label}.ndjson")

        print(f"🔍 [{label}] ← {list_label} 기반 → {info_func.__name__} 호출 중...")
        for item in tqdm(data):
            id_value = item.get(key_name)
            if id_value:
                result = info_func(id_value)
                if isinstance(result, dict):
                    append_ndjson([result], output_path, key_name=key_name)


# ✅ 단독 실행 시
if __name__ == "__main__":
    # 전체 실행
    # run_info_scraper()

    # 또는 일부만 실행
    run_info_scraper(target_labels=[
        # "안전점검대상_지하시설물_정보",
        # "안전점검대상_지하시설물_점검결과",
        # "전문기관_실적",
        # "지반침하_안전조치내용",
        # "지반침하_응급조치내용",
        # "중점관리대상_정보"
    ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 38
#      31     return new_count
#      34 # 🔁 리스트 ↔ 정보 매핑 (list_from 추가됨)
#      35 info_api_mapping = {
#      36     "지하안전평가_정보": {
#      37         "key": "evalNo",
# ---> 38         "func": get_impat_evaluation_info,
#      39         "list_from": "지하안전평가_리스트"
#      40     },
#      41     "소규모지하안전평가_정보": {
#      42         "key": "evalNo",
#      43         "func": get_small_impat_evaluation_info,
#      44         "list_from": "소규모지하안전평가_리스트"
#      45     },
#      46     "착공후지하안전조사_정보": {
#      47         "key": "evalNo",
#      48         "func": get_post_construction_check_info,
#      49         "list_from": "착공후지하안전조사_리스트"
#      50     },
#      51     "안전점검대상_지하시설물_정보": {
#      52         "key": "facilNo",
#      53         "func": get_underground_facility_info,
#      54         "list_from": "안전점검대상_지하시설물_리스트"
#      55     },
#      56     "안전점검대상_지하시설물_점검결과": {
#      57         "key": "facilNo",
#      58         "func": get_underground_facility_result,
#      59         "list_from": "안전점검대상_지하시설물_리스트"
#      60     },
#      61     "지반침하사고_정보": {
#      62         "key": "sagoNo",
#      63         "func": get_subsidence_accident_info,
#      64         "list_from": "지반침하사고_리스트"
#      65     },
#      66     "전문기관_정보": {
#      67         "key": "corpCd",
#      68         "func": get_agency_info,
#      69         "list_from": "전문기관_리스트"
#      70     },
#      71     "전문기관_실적": {
#      72         "key": "corpCd",
#      73         "func": get_agency_results,
#      74         "list_from": "전문기관_리스트"
#      75     },
#      76     "지하개발사업_정보": {
#      77         "key": "saupNo",
#      78         "func": get_underground_project_info,
#      79         "list_from": "지하개발사업_리스트"
#      80     },
#      81     "지반침하_안전조치내용": { # 안 줌
#      82         "key": "evalNo",
#      83         "func": get_risk_safety_info,
#      84         "list_from": "지반침하위험도평가_리스트"
#      85     },
#      86     "지반침하_응급조치내용": { # 안 줌
#      87         "key": "evalNo",
#      88         "func": get_risk_emergency_info,
#      89         "list_from": "지반침하위험도평가_리스트"
#      90     },
#      91     "중점관리대상_정보": { # 안 줌
#      92         "key": "facilNo",
#      93         "func": get_priority_control_info,
#      94         "list_from": "중점관리대상_리스트"
#      95     }
#      96 }
#      99 # ✅ 확장된 실행 함수 (리스트 공유 처리 포함)
#     100 def run_info_scraper(list_base_path: str = "Database/openapi", target_labels: Optional[List[str]] = None):
#     101     # 1. 필요한 리스트만 한 번씩 불러옴
#
# NameError: name 'get_impat_evaluation_info' is not defined

# %% [markdown]
# ## json to csv

# %%
import os
import json
import csv

def convert_json_to_csv(json_path, csv_path):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    if isinstance(data, dict):
        data = [data]
    if not data:
        return

    with open(csv_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=data[0].keys())
        writer.writeheader()
        writer.writerows(data)

import os
import json
import csv

def extract_items_from_ndjson(ndjson_path, csv_path):
    rows = []

    with open(ndjson_path, "r", encoding="utf-8") as f:
        for line in f:
            try:
                obj = json.loads(line.strip())
                items = obj.get("response", {}).get("body", {}).get("items", [])

                if isinstance(items, list):
                    rows.extend(items)
                elif isinstance(items, dict):  # 단일 item일 수도 있음
                    rows.append(items)

            except Exception as e:
                print(f"⚠️ 오류 발생: {e}")

    if not rows:
        print(f"🚫 저장할 데이터 없음: {ndjson_path}")
        return

    # CSV로 저장
    with open(csv_path, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.DictWriter(f, fieldnames=rows[0].keys())
        writer.writeheader()
        writer.writerows(rows)

    print(f"✅ 저장 완료: {csv_path}")


def convert_all_ndjson_items_to_csv(base_dir="Database/openapi"):
    for filename in os.listdir(base_dir):
        if filename.endswith(".ndjson") and not filename.startswith("test"):
            ndjson_path = os.path.join(base_dir, filename)
            csv_path = os.path.join(base_dir, filename.replace(".ndjson", ".csv"))
            extract_items_from_ndjson(ndjson_path, csv_path)

# 실행
if __name__ == "__main__":
    convert_all_ndjson_items_to_csv()
# Out:
# ✅ 저장 완료: Database/openapi/안전점검대상_지하시설물_점검결과.csv
# ✅ 저장 완료: Database/openapi/지하개발사업_정보.csv
# ✅ 저장 완료: Database/openapi/지반침하사고_정보.csv
# ✅ 저장 완료: Database/openapi/안전점검대상_지하시설물_정보.csv
# ✅ 저장 완료: Database/openapi/소규모지하안전평가_정보.csv
# ✅ 저장 완료: Database/openapi/지반침하_응급조치내용.csv
# ✅ 저장 완료: Database/openapi/착공후지하안전조사_정보.csv
# ✅ 저장 완료: Database/openapi/지반침하_안전조치내용.csv
# ✅ 저장 완료: Database/openapi/전문기관_실적.csv
# ✅ 저장 완료: Database/openapi/전문기관_정보.csv
# ✅ 저장 완료: Database/openapi/지하안전평가_정보.csv

# %% [markdown]
# # 전처리

# %% [markdown]
# ## addr 병합

# %%
import os
import pandas as pd

def merge_address_columns(csv_path: str):
    df = pd.read_csv(csv_path, dtype=str)

    # NaN 방지 및 공백 제거
    for col in ["sido", "sigungu", "dong", "addr"]:
        if col in df.columns:
            df[col] = df[col].fillna("").astype(str).str.strip()
        else:
            print(f"🚨 누락된 컬럼: {col}")
            return

    # 병합 수행
    df["addr"] = df["sido"] + " " + df["sigungu"] + " " + df["dong"] + " " + df["addr"]
    df["addr"] = df["addr"].str.replace(r"\s+", " ", regex=True).str.strip()

    # 저장 (덮어쓰기)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")
    print(f"✅ 병합 및 저장 완료: {csv_path}")

def merge_all_in_folder(base_dir="Database/openapi"):
    for filename in os.listdir(base_dir):
        if filename.endswith(".csv") and not filename.startswith("test"):
            csv_path = os.path.join(base_dir, filename)
            merge_address_columns(csv_path)

# 실행
if __name__ == "__main__":
    merge_all_in_folder()
# Out:
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: dong
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# ✅ 병합 및 저장 완료: Database/openapi/지반침하사고_정보.csv
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido
# 🚨 누락된 컬럼: sido

# %% [markdown]
# ## addr to latlog

# %%
import os
import pandas as pd
import requests
import time
from dotenv import load_dotenv
from tqdm import tqdm

# .env 파일에서 환경변수 불러오기
load_dotenv()
KAKAO_REST_API_KEY = os.getenv("KAKAO_REST_API_KEY")

def get_coords_from_address(address: str):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {KAKAO_REST_API_KEY}"}
    params = {"query": address}
    try:
        print(f"📤 요청 주소: {address}")
        response = requests.get(url, headers=headers, params=params)
        print(f"📥 응답 코드: {response.status_code}")
        
        if response.status_code == 200:
            result = response.json()
            documents = result.get("documents", [])
            print(f"📄 documents: {documents}")

            if documents:
                x = documents[0]["x"]  # longitude
                y = documents[0]["y"]  # latitude
                return y, x
            else:
                print(f"⚠️ 문서 없음 (주소 인식 실패): {address}")
        else:
            print(f"❌ 응답 실패: {response.text}")

    except Exception as e:
        print(f"❌ 예외 발생: {address} → {e}")
    return None, None

# %%
def fill_latlng_from_address(csv_path: str):
    print(f"▶️ 시작: {csv_path}")  # 시작 로그

    df = pd.read_csv(csv_path, dtype=str)
    
    if "addr" not in df.columns:
        print(f"🚨 addr 컬럼 없음: {csv_path}")
        return

    if "sagoLat" not in df.columns:
        df["sagoLat"] = ""
    if "sagoLon" not in df.columns:
        df["sagoLon"] = ""

    # NaN 처리
    df["sagoLat"] = df["sagoLat"].fillna("")
    df["sagoLon"] = df["sagoLon"].fillna("")

    to_fill = ((df["sagoLat"] == "") | (df["sagoLon"] == "")).sum()
    print(f"📌 좌표 채워야 할 행 수: {to_fill}")

    updated_count = 0

    for idx, row in tqdm(df.iterrows(), total=len(df), desc=os.path.basename(csv_path)):
        if not row["sagoLat"] or not row["sagoLon"]:
            address = row["addr"].split(",")[0].split("(")[0].strip()
            lat, lon = get_coords_from_address(address)
            if lat and lon:
                df.at[idx, "sagoLat"] = lat
                df.at[idx, "sagoLon"] = lon
                updated_count += 1
                print(f"📍 {address} → {lat}, {lon}")
            else:
                print(f"⚠️ 좌표 없음: {address}")
            time.sleep(0.3)

            if updated_count > 0 and updated_count % 5 == 0:
                df.to_csv(csv_path, index=False, encoding="utf-8-sig")
                print(f"💾 임시 저장 완료 (누적 {updated_count}개): {csv_path}")

    df.to_csv(csv_path, index=False, encoding="utf-8-sig")
    print(f"✅ 최종 저장 완료: {csv_path}")


def fill_selected_csv_latlng(filename: str, base_dir="Database/openapi"):
    csv_path = os.path.join(base_dir, filename)
    if os.path.exists(csv_path):
        print("✅ 실행 시작")
        fill_latlng_from_address(csv_path)
    else:
        print(f"❌ 파일 없음: {csv_path}")

# %%
# 실행
if __name__ == "__main__":
    # 예시: 지반침하사고_정보.csv 하나만 실행
    fill_selected_csv_latlng("seoul/지반침하사고_정보_위경도 채움.csv")
# Out:
# ✅ 실행 시작
# ▶️ 시작: Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv
# 📌 좌표 채워야 할 행 수: 7
# 지반침하사고_정보_위경도 채움.csv:   0%|          | 0/133 [00:00<?, ?it/s]
# 📤 요청 주소: 서울특별시 관악구 보라매로 21
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 관악구 봉천동 732-17', 'b_code': '1162010100', 'h_code': '1162052500', 'main_address_no': '732', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '관악구', 'region_3depth_h_name': '보라매동', 'region_3depth_name': '봉천동', 'sub_address_no': '17', 'x': '126.926771137944', 'y': '37.4913731093454'}, 'address_name': '서울 관악구 보라매로 21', 'address_type': 'ROAD_ADDR', 'road_address': {'address_name': '서울 관악구 보라매로 21', 'building_name': '창암빌딩', 'main_building_no': '21', 'region_1depth_name': '서울', 'region_2depth_name': '관악구', 'region_3depth_name': '봉천동', 'road_name': '보라매로', 'sub_building_no': '', 'underground_yn': 'N', 'x': '126.926771137944', 'y': '37.4913731093454', 'zone_no': '08708'}, 'x': '126.926771137944', 'y': '37.4913731093454'}]
# 📍 서울특별시 관악구 보라매로 21 → 37.4913731093454, 126.926771137944
# 지반침하사고_정보_위경도 채움.csv:   8%|▊         | 11/133 [00:00<00:04, 29.74it/s]
# 📤 요청 주소: 서울특별시 강서구 방화대로 360
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 강서구 마곡동 1313', 'b_code': '1150010500', 'h_code': '1150063000', 'main_address_no': '1313', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '강서구', 'region_3depth_h_name': '방화1동', 'region_3depth_name': '마곡동', 'sub_address_no': '', 'x': '126.816984735352', 'y': '37.5729325838338'}, 'address_name': '서울 강서구 방화대로 360', 'address_type': 'ROAD_ADDR', 'road_address': {'address_name': '서울 강서구 방화대로 360', 'building_name': '', 'main_building_no': '360', 'region_1depth_name': '서울', 'region_2depth_name': '강서구', 'region_3depth_name': '마곡동', 'road_name': '방화대로', 'sub_building_no': '', 'underground_yn': 'N', 'x': '126.816984735352', 'y': '37.5729325838338', 'zone_no': '07592'}, 'x': '126.816984735352', 'y': '37.5729325838338'}]
# 📍 서울특별시 강서구 방화대로 360 → 37.5729325838338, 126.816984735352
# 지반침하사고_정보_위경도 채움.csv:  14%|█▍        | 19/133 [00:00<00:04, 25.11it/s]
# 📤 요청 주소: 서울특별시 성동구 살곶이2길 1
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 성동구 마장동 785-3', 'b_code': '1120010500', 'h_code': '1120054000', 'main_address_no': '785', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '성동구', 'region_3depth_h_name': '마장동', 'region_3depth_name': '마장동', 'sub_address_no': '3', 'x': '127.046839691464', 'y': '37.5653203768813'}, 'address_name': '서울 성동구 살곶이2길 1', 'address_type': 'ROAD_ADDR', 'road_address': {'address_name': '서울 성동구 살곶이2길 1', 'building_name': '', 'main_building_no': '1', 'region_1depth_name': '서울', 'region_2depth_name': '성동구', 'region_3depth_name': '마장동', 'road_name': '살곶이2길', 'sub_building_no': '', 'underground_yn': 'N', 'x': '127.046839691464', 'y': '37.5653203768813', 'zone_no': '04761'}, 'x': '127.046839691464', 'y': '37.5653203768813'}]
# 📍 서울특별시 성동구 살곶이2길 1 → 37.5653203768813, 127.046839691464
# 지반침하사고_정보_위경도 채움.csv:  17%|█▋        | 22/133 [00:01<00:06, 17.06it/s]
# 📤 요청 주소: 서울특별시 종로구 통일로12길 78
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 종로구 행촌동 210-53', 'b_code': '1111018100', 'h_code': '1111058000', 'main_address_no': '210', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '종로구', 'region_3depth_h_name': '교남동', 'region_3depth_name': '행촌동', 'sub_address_no': '53', 'x': '126.962023655327', 'y': '37.5757495176565'}, 'address_name': '서울 종로구 통일로12길 78', 'address_type': 'ROAD_ADDR', 'road_address': {'address_name': '서울 종로구 통일로12길 78', 'building_name': '', 'main_building_no': '78', 'region_1depth_name': '서울', 'region_2depth_name': '종로구', 'region_3depth_name': '행촌동', 'road_name': '통일로12길', 'sub_building_no': '', 'underground_yn': 'N', 'x': '126.962023655327', 'y': '37.5757495176565', 'zone_no': '03026'}, 'x': '126.962023655327', 'y': '37.5757495176565'}]
# 📍 서울특별시 종로구 통일로12길 78 → 37.5757495176565, 126.962023655327
# 지반침하사고_정보_위경도 채움.csv:  21%|██        | 28/133 [00:01<00:06, 16.56it/s]
# 📤 요청 주소: 서울특별시 동작구 상도동 368-6
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 동작구 상도동 368-6', 'b_code': '1159010200', 'h_code': '1159054000', 'main_address_no': '368', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '동작구', 'region_3depth_h_name': '상도2동', 'region_3depth_name': '상도동', 'sub_address_no': '6', 'x': '126.938942573289', 'y': '37.5044489430148'}, 'address_name': '서울 동작구 상도동 368-6', 'address_type': 'REGION_ADDR', 'road_address': {}, 'x': '126.938942573289', 'y': '37.5044489430148'}]
# 📍 서울특별시 동작구 상도동 368-6 → 37.5044489430148, 126.938942573289
# 지반침하사고_정보_위경도 채움.csv:  52%|█████▏    | 69/133 [00:01<00:01, 50.28it/s]
# 💾 임시 저장 완료 (누적 5개): Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv
# 📤 요청 주소: 서울특별시 용산구 도원동 9-298
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 용산구 도원동 9-298', 'b_code': '1117012000', 'h_code': '1117059000', 'main_address_no': '9', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '용산구', 'region_3depth_h_name': '용문동', 'region_3depth_name': '도원동', 'sub_address_no': '298', 'x': '126.956975102391', 'y': '37.5399094500815'}, 'address_name': '서울 용산구 도원동 9-298', 'address_type': 'REGION_ADDR', 'road_address': {}, 'x': '126.956975102391', 'y': '37.5399094500815'}]
# 📍 서울특별시 용산구 도원동 9-298 → 37.5399094500815, 126.956975102391
# 지반침하사고_정보_위경도 채움.csv:  59%|█████▉    | 79/133 [00:02<00:01, 42.55it/s]
# 📤 요청 주소: 서울특별시 구로구 디지털로 231
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 구로구 가리봉동 131-11', 'b_code': '1153010300', 'h_code': '1153059500', 'main_address_no': '131', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '구로구', 'region_3depth_h_name': '가리봉동', 'region_3depth_name': '가리봉동', 'sub_address_no': '11', 'x': '126.891282956636', 'y': '37.48076326519'}, 'address_name': '서울 구로구 디지털로 231', 'address_type': 'ROAD_ADDR', 'road_address': {'address_name': '서울 구로구 디지털로 231', 'building_name': '', 'main_building_no': '231', 'region_1depth_name': '서울', 'region_2depth_name': '구로구', 'region_3depth_name': '가리봉동', 'road_name': '디지털로', 'sub_building_no': '', 'underground_yn': 'N', 'x': '126.891282956636', 'y': '37.48076326519', 'zone_no': '08388'}, 'x': '126.891282956636', 'y': '37.48076326519'}]
# 📍 서울특별시 구로구 디지털로 231 → 37.48076326519, 126.891282956636
# 지반침하사고_정보_위경도 채움.csv: 100%|██████████| 133/133 [00:02<00:00, 51.08it/s]
# ✅ 최종 저장 완료: Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv

# %% [markdown]
# - 테스트

# %%
def test_specific_address(address: str):
    lat, lon = get_coords_from_address(address)
    if lat and lon:
        print(f"📍 {address} → 위도: {lat}, 경도: {lon}")
    else:
        print(f"❌ 변환 실패: {address}")

if __name__ == "__main__":
    # 테스트 주소 직접 입력
    test_specific_address("서울특별시 용산구 도원동 9-298")
# Out:
# 📤 요청 주소: 서울특별시 용산구 도원동 9-298
# 📥 응답 코드: 200
# 📄 documents: [{'address': {'address_name': '서울 용산구 도원동 9-298', 'b_code': '1117012000', 'h_code': '1117059000', 'main_address_no': '9', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '용산구', 'region_3depth_h_name': '용문동', 'region_3depth_name': '도원동', 'sub_address_no': '298', 'x': '126.956975102391', 'y': '37.5399094500815'}, 'address_name': '서울 용산구 도원동 9-298', 'address_type': 'REGION_ADDR', 'road_address': {}, 'x': '126.956975102391', 'y': '37.5399094500815'}]
# 📍 서울특별시 용산구 도원동 9-298 → 위도: 37.5399094500815, 경도: 126.956975102391

# %% [markdown]
# - 테스트 : 키워드 검색

# %%
def get_coords_from_keyword(keyword: str):
    url = "https://dapi.kakao.com/v2/local/search/keyword.json"
    headers = {"Authorization": f"KakaoAK {KAKAO_REST_API_KEY}"}
    params = {"query": keyword}
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            documents = response.json().get("documents", [])
            if documents:
                x = documents[0]["x"]
                y = documents[0]["y"]
                return y, x
            else:
                print(f"⚠️ 결과 없음 (keyword API): {keyword}")
        else:
            print(f"❌ 요청 실패: {response.status_code}")
    except Exception as e:
        print(f"❌ 예외 발생: {e}")
    return None, None

# %%
address = "서울특별시 동작구 상도로 162"
lat, lon = get_coords_from_keyword(address)
print(f"{address} → {lat}, {lon}")
# Out:
# ⚠️ 결과 없음 (keyword API): 서울특별시 동작구 상도로 162
# 서울특별시 동작구 상도로 162 → None, None

# %% [markdown]
# ### 위경도 처리 잘 됐는지 확인

# %%
import pandas as pd
import os

def check_missing_latlon(csv_path: str):
    if not os.path.exists(csv_path):
        print(f"❌ 파일 없음: {csv_path}")
        return

    df = pd.read_csv(csv_path, dtype=str)

    if "sagoLat" not in df.columns or "sagoLon" not in df.columns:
        print("🚨 'sagoLat' 또는 'sagoLon' 컬럼이 존재하지 않습니다.")
        return

    # 결측값 필터링
    missing = df[(df["sagoLat"].isna()) | (df["sagoLat"] == "") |
                 (df["sagoLon"].isna()) | (df["sagoLon"] == "")]
    
    if missing.empty:
        print("✅ 위경도 누락된 행이 없습니다.")
    else:
        print(f"⚠️ 위경도 누락 행 수: {len(missing)}")
        print(missing[["addr", "sagoLat", "sagoLon"]])

# 실행 예시
if __name__ == "__main__":
    csv_file = "Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv"
    check_missing_latlon(csv_file)
# Out:
# ✅ 위경도 누락된 행이 없습니다.

# %% [markdown]
# - 서울특별시 관악구 보라매로 21 (봉천동)
# - 서울특별시 강서구 방화대로 360 (마곡동)
# - 서울특별시 성동구 살곶이2길 1 (마장동)
# - 서울특별시 동작구 상도동 185-1 -> 37.503595250356625, 126.93726921197452
# - 서울특별시 종로구 통일로12길 78 (행촌동)
# - 서울특별시 강동구 고덕동 217 -> 37.55585, 127.1593
# - 서울특별시 성북구 장위동 124-29 -> 37.61784, 127.0561
# - 서울특별시 동작구 상도동 368-6
# - 서울특별시 용산구 도원동 9-298
# - 37.54043, 127.1166
# - 서울특별시 구로구 디지털로 231 # 부정확함

# %%
df = pd.read_csv("Database/openapi/seoul/지반침하사고_정보.csv", dtype=str)

# 주소 보정 및 위경도 직접 할당
df.loc[10, "addr"] = "서울특별시 관악구 보라매로 21 (봉천동)"
df.loc[18, "addr"] = "서울특별시 강서구 방화대로 360 (마곡동)"
df.loc[21, "addr"] = "서울특별시 성동구 살곶이2길 1 (마장동)"
df.loc[25, "addr"] = "서울특별시 동작구 상도동 185-1"
df.loc[25, "sagoLat"] = "37.503595250356625"
df.loc[25, "sagoLon"] = "126.93726921197452"
df.loc[27, "addr"] = "서울특별시 종로구 통일로12길 78 (행촌동)"
df.loc[31, "addr"] = "서울특별시 강동구 고덕동 217"
df.loc[31, "sagoLat"] = "37.55585"
df.loc[31, "sagoLon"] = "127.1593"
df.loc[54, "addr"] = "서울특별시 성북구 장위동 124-29"
df.loc[54, "sagoLat"] = "37.61784"
df.loc[54, "sagoLon"] = "127.0561"
df.loc[68, "addr"] = "서울특별시 동작구 상도동 368-6"
df.loc[78, "addr"] = "서울특별시 용산구 도원동 9-298"
df.loc[82, "sagoLat"] = "37.54043"
df.loc[82, "sagoLon"] = "127.1166"
df.loc[109, "addr"] = "서울특별시 구로구 디지털로 231"  # 정확한 위치 불확실, 참고용

# %%
df.to_csv("Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## 원인 전처리

# %%
df = pd.read_csv("Database/openapi/seoul/지반침하사고_정보_위경도 채움.csv", dtype=str)

# %%
def insert_labels_to_column(df, labels, start_idx=0):
    """
    sagoDetailProcessed 컬럼에 지정한 라벨 리스트를 해당 인덱스에 맞게 삽입합니다.

    Args:
        df (pd.DataFrame): 원본 DataFrame
        labels (list): 각 행에 삽입할 라벨 리스트
        start_idx (int): 시작 인덱스 (기본값은 0)

    Returns:
        pd.DataFrame: 수정된 DataFrame
    """
    end_idx = start_idx + len(labels)
    
    # 컬럼 없으면 생성
    if "sagoDetailProcessed" not in df.columns:
        df["sagoDetailProcessed"] = ""

    for i, label in enumerate(labels):
        df.at[start_idx + i, "sagoDetailProcessed"] = label

    return df

# %%
import pandas as pd

# 잘림 없이 전체 텍스트 출력 설정
pd.set_option("display.max_colwidth", None)

index = 0
# 예시: 앞 20개만 출력
print(df["sagoDetail"].iloc[index:index + 20])
# Out:
# 0                               열수송관(D600mm) 노후 손상으로 함몰 발생\n(굴착복구 미흡분야로 관리)
# 1                           상수관(？300mm)에서 분기된 소화전 연결관(？100mm) 동파로 누수되어 함몰발생
# 2                                           KT 통신맨홀 슬라브 파손\n(굴착복구 미흡분야로 관리)
# 3                                                  하수관로(D450㎜) 노후？파손으로 토사유실
# 4                          인근 공사차량(레미콘차) 중량에 의한 노후 하수박스 상판파손(하수박스 1946년 부설)
# 5                                           폐쇄된 빗물받이 연결관을 폐관처리 하지 않아 토사가 유실
# 6                                              우수관로(D1000mm) 노후파손으로 인한 토사유입
# 7                                                       공공하수관 노후 손상되어 토사 유실
# 8                                                      하수관 연결부 이격으로 인한 토사유입
# 9                  지하철 7호선 공사시 설치한 가시설(H-beam)인접 다짐불량, 토류판 부식 등 장기침하로 인한 함몰
# 10                                                폐쇄되지 않은 폐 빗물받이연결관으로 토사 유실
# 11             상수도 이설구간 접합부(700mm에서 300mm로 분기)에서  외부 진동, 압력 등에 의한 파열로 누수 발생
# 12                                                     굴착복구 다짐 미흡으로 인한 장기침하
# 13                                               상수도관 및 통신관 매설 시 하수관로 파손 추정
# 14                                     주변 사각형거의 바닥 세굴 및 파손, 벽체 및 슬래브 노후화 심화
# 15                                              하수관과 맨홀 접속부 이음 불량으로 인한 도로침하
# 16    건축공사장 인입 상수도 맨홀 하중 등으로 하수관 처짐발생->하수가 공사장 내부로 토립자와 함께 유출되어 지반(보도)침하 발생
# 17                               노후하수관(1,200mm)손상 및 연결관 접속부 미폐쇄 조치로 지반침하 발생
# 18                                               굴착원인조사 결과 원인불명(굴착복구 불량 추정)
# 19                                                 노후하수관-하수맨홀 연결부 파손으로 지반침하
# Name: sagoDetail, dtype: object

# %%
labels = [
["노후 지하시설물", "굴착/복구 불량"],  # 0: 열수송관 노후 + 복구 미흡 관리
"노후 지하시설물",                  # 1: 상수관 동파 누수
["노후 지하시설물", "굴착/복구 불량"],  # 2: 슬라브 파손 + 복구 미흡
["노후 지하시설물", "지반 약화"],     # 3: 노후 하수관 파손 → 토사유실
["공사 영향", "노후 지하시설물"],     # 4: 공사차량 영향 + 노후 하수박스
"설계/시공 오류",                  # 5: 폐쇄하지 않은 연결관
["노후 지하시설물", "지반 약화"],     # 6: 노후 우수관 파손 → 유입
["노후 지하시설물", "지반 약화"],     # 7: 하수관 손상 → 유실
["설계/시공 오류", "지반 약화"],      # 8: 이격 → 토사 유입
["공사 영향", "굴착/복구 불량"],      # 9: 가시설 영향 + 다짐불량 등
"설계/시공 오류",                  # 10: 폐쇄 안 된 연결관
"노후 지하시설물",                 # 11: 상수도 접합부 파열 누수
"굴착/복구 불량",                 # 12: 다짐 미흡
"지하시설물 영향",                 # 13: 매설 중 하수관 파손
"노후 지하시설물",                 # 14: 슬래브 및 벽체 노후화
"설계/시공 오류",                 # 15: 맨홀 접속부 이음 불량
["공사 영향", "설계/시공 오류"],     # 16: 공사장 인입 및 접속부 처리 미흡
"노후 지하시설물",                 # 17: 하수관 손상 + 접속부 미폐쇄
"기타 / 미상",                   # 18: 원인불명 (추정)
"노후 지하시설물",                 # 19: 하수맨홀 연결부 파손
["노후 지하시설물", "설계/시공 오류", "자연재해"],  # 20: 노후관 + 연결부 이격 + 집중호우
"노후 지하시설물",                         # 21: 상수도관 부식
"노후 지하시설물",                         # 22: 미철거 + 손괴
["공사 영향", "자연재해", "지반 약화"],         # 23: 집중호우 + 토사 유입 + 침하
["설계/시공 오류", "지반 약화"],              # 24: 이음부 이격 → 유실
"기타 / 미상",                           # 25: 장기침하 추정 (불명확)
"굴착/복구 불량",                         # 26: 다짐불량, 압밀침하
"노후 지하시설물",                         # 27: 차량진동 → 상수도관 누수
["설계/시공 오류", "지반 약화"],              # 28: 접합부 파손 → 토사 유출
["노후 지하시설물", "지반 약화", "기타 / 미상"], # 29: 파손 + 조사 중
"지반 약화",                             # 30: 장기 압밀침하
"설계/시공 오류",                         # 31: 접속부 시공불량
["노후 지하시설물", "설계/시공 오류"],         # 32: 접속부 불량
["노후 지하시설물", "지반 약화"],             # 33: 상수도관 누수 → 토사유실
["공사 영향", "지반 약화"],                 # 34: 중차량 하중 → 침하
"굴착/복구 불량",                         # 35: 장기침하
["설계/시공 오류", "지반 약화"],              # 36: 접합 불량 + 쇄굴
["공사 영향", "노후 지하시설물", "설계/시공 오류"], # 37: 복합요인, 공사장, 노후관, 손괴
"설계/시공 오류",                         # 38: 접합부 결함
"지반 약화",                              # 39: 장기압밀 침하
"노후 지하시설물",                            # 40: 하수관 연결부 파손
"노후 지하시설물",                            # 41: 상수도관 누수
"설계/시공 오류",                             # 42: 빗물받이 벽체 파손
"기타 / 미상",                               # 43: 점검 이상 없음, 원인 불명
"설계/시공 오류",                             # 44: 엘리베이터 설치 부실
"설계/시공 오류",                             # 45: 통신관 하부 빈 공간
"노후 지하시설물",                            # 46: 맨홀 하부 구체 파손
["노후 지하시설물", "설계/시공 오류"],          # 47: 하수관 이격, 라이닝 변형
"노후 지하시설물",                            # 48: 하수맨홀 하부 파손
"노후 지하시설물",                            # 49: 하수관 노후화로 인한 동공
["설계/시공 오류", "기타 / 미상"],             # 50: 폐하수관 존치, 매립물
["자연재해", "설계/시공 오류", "지반 약화"],    # 51: 호우 + 토류벽 유실 + 접합부 파손
"노후 지하시설물",                            # 52: 차량진동 → 상수도 누수
"지반 약화",                                 # 53: 침하로 동공 발생
["공사 영향", "지반 약화"],                   # 54: 공사장 차수 불량 → 지하수위 침하
["설계/시공 오류", "공사 영향"],              # 55: 접합불량 + 신설 하수관 공사장
["노후 지하시설물", "공사 영향"],             # 56: 벽체·슬래브 노후 + 중차량 진입
"공사 영향",                                 # 57: 건축현장 지하공사
"노후 지하시설물",                            # 58: 강관(1970년 부설) 용접부 파손
["공사 영향", "기타 / 미상"],                 # 59: 민간 아파트 굴착공사 중 사고 추정
"노후 지하시설물",                        # 60: 하수관 이음부 이격
"원인불명/기타",                         # 61: 원인조사 필요
"지반 약화",                             # 62: 지하수로 인한 토사 유출
["자연재해", "노후 지하시설물"],         # 63: 집중호우 + 하수박스 파손
"원인불명/기타",                         # 64: NaN
"지하시설물 영향",                      # 65: 주변 지하매설물 이상 추정
"설계/시공 오류",                       # 66: 배수시설 연결관 접합불량
"원인불명/기타",                         # 67: 원인미상
["공사 영향", "굴착/복구 불량"],         # 68: 승강편의시설 공사 + 다짐불량 + 집중호우
["공사 영향", "자연재해"],              # 69: 집중호우 + 공사장 하수관 월류
"노후 지하시설물",                        # 70: 개인 사유지 노후 하수관
["자연재해", "설계/시공 오류"],         # 71: 집중호우 + 배수설비 파손
"지반 약화",                             # 72: 통신관로 주변 침하
"노후 지하시설물",                        # 73: 하수관 파손
"굴착/복구 불량",                        # 74: 다짐불량
"설계/시공 오류",                       # 75: 가정하수관 연결부 파손
"공사 영향",                             # 76: 건축물 신축 공사장 인근
"설계/시공 오류",                       # 77: 가시설 미제거 + 통신케이블 처짐
"노후 지하시설물",                        # 78: 흄관 파손
"설계/시공 오류",                        # 79: 하수관 이음부 이격
"굴착/복구 불량",          # 80: 되메우기 다짐불량
"굴착/복구 불량",          # 81: 다짐불량
["공사 영향", "지반 약화"], # 82: 공사 인접 + 우천 토사유실
["공사 영향", "자연재해"],  # 83: 신설공사 + 우천
["공사 영향", "설계/시공 오류"], # 84: 공사 중 이음부 이격 및 누수
"노후 지하시설물",         # 85: 하수박스 파손
"노후 지하시설물",         # 86: 노후 하수관 파손
"노후 지하시설물",         # 87: 하수박스 외벽 파손
"설계/시공 오류",          # 88: 접속부 불량, 이음부 이격
"지반 약화",              # 89: 토사 유출 지속 → 지반침하
["노후 지하시설물", "자연재해"], # 90: 타관통과 + 집중호우
"노후 지하시설물",         # 91: 폐쇄 상수관로 접합부 손상
"노후 지하시설물",         # 92: 상수도 누수
"지반 약화",              # 93: 부등침하 → 파손
"노후 지하시설물",         # 94: 상수도 누수 → 하수관 이격
"노후 지하시설물",         # 95: 하수관 맨홀 이상
"기타 / 미상",            # 96: 불명 조적구조물 파손 (구조물 종류 불명확)
"노후 지하시설물",         # 97: 상수관 손상 누수
"굴착/복구 불량",          # 98: 다짐불량
"설계/시공 오류",           # 99: 빗물받이 연결관 미폐공
["공사 영향", "자연재해"],      # 100: 해빙기 공사 + 토사유실
"노후 지하시설물",              # 101: 노후·파손 빗물받이 연결관
"노후 지하시설물",              # 102: 하수맨홀과 하수관 이음부 파손
"노후 지하시설물",              # 103: 상수관 누수
"자연재해",                     # 104: 집중호우
"기타 / 미상",                 # 105: 원인 미상
"지반 약화",                   # 106: 연약지반 장기압밀침하
"굴착/복구 불량",              # 107: 하수박스 연결부 채움재 불량
"지반 약화",                   # 108: 장기 압밀침하
"노후 지하시설물",              # 109: 하수박스 파손
"기타 / 미상",                 # 110: NaN
"노후 지하시설물",              # 111: 체신(통신)맨홀 파손
["공사 영향", "지반 약화"],      # 112: 공사장 지하수 유출 → 토사유실
"노후 지하시설물",              # 113: 수도 누수 → 하수관(폐관) 파손
"굴착/복구 불량",              # 114: 맨홀 박스 주변 다짐 불량
["공사 영향", "설계/시공 오류"], # 115: 추진공사 + 그라우팅 미실시
"설계/시공 오류",              # 116: 하수관로 접합부 이탈
"노후 지하시설물",              # 117: 하수도 노후화
"기타 / 미상",                 # 118: 원인 불명
"기타 / 미상",                  # 119: 조사중
"기타 / 미상",            # 120: 단순 도로침하
"지반 약화",              # 121: 장기 침하 등 추정
"노후 지하시설물",        # 122: 하수맨홀 하부슬라브 파손 → 하수 유출
"노후 지하시설물",        # 123: 수도 누수
"노후 지하시설물",        # 124: 하수관로 파손
"노후 지하시설물",        # 125: 하수맨홀 구체 파손
"지반 약화",              # 126: 토양의 압밀 침하
"지반 약화",              # 127: 토사 유실로 인한 단순 침하
"굴착/복구 불량",         # 128: 공사 다짐 불량
"설계/시공 오류",         # 129: 기존관·신설관 이음부 이격
"굴착/복구 불량",         # 130: 가시설 주변 토류판 부식
"굴착/복구 불량",         # 131: 가시설 주변 장기 지반침하
"노후 지하시설물"         # 132: 하수관 파손
]

len(labels), len(df), index, df.shape
# Out:
# (133, 133, 0, (133, 22))

# %%
df = insert_labels_to_column(df, labels, start_idx=index)
df["sagoDetailProcessed"].iloc[:]
# Out:
# 0      [노후 지하시설물, 굴착/복구 불량]
# 1                  노후 지하시설물
# 2      [노후 지하시설물, 굴착/복구 불량]
# 3         [노후 지하시설물, 지반 약화]
# 4         [공사 영향, 노후 지하시설물]
#                ...
# 128                굴착/복구 불량
# 129                설계/시공 오류
# 130                굴착/복구 불량
# 131                굴착/복구 불량
# 132                노후 지하시설물
# Name: sagoDetailProcessed, Length: 133, dtype: object

# %%
df.to_csv("Database/openapi/seoul/지반침하사고_정보_위경도_채움.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## 복구 방법 전처리

# %%
df = pd.read_csv("Database/openapi/seoul/지반침하사고_정보_위경도_채움.csv", dtype=str)
df
# Out:
#        sagoNo   sido sigungu   dong                               addr  \
# 0    20180001  서울특별시     강남구    삼성동    서울특별시 강남구 삼성동 147-2앞 (봉은사로 86길)
# 1    20180002  서울특별시     송파구    삼전동    서울특별시 송파구 삼전동 180-6 (백제고분로 272)
# 2    20180003  서울특별시     구로구    구로동     서울특별시 구로구 구로동 723-16 (구로동로17길)
# 3    20180004  서울특별시    영등포구  당산동4가   서울특별시 영등포구 당산동4가 93-5 (국회대로 539)
# 4    20180005  서울특별시    영등포구  양평동4가  서울특별시 영등포구 양평동4가 23-2 (양평로19길 19)
# ..        ...    ...     ...    ...                                ...
# 128  20250049  서울특별시     강남구    도곡동                서울특별시 강남구 도곡동 543-7
# 129  20250053  서울특별시    동대문구    회기동              서울특별시 동대문구 회기동 60-104
# 130  20250056  서울특별시     서초구    서초동           서울특별시 서초구 서초동 사평대로 376-2
# 131  20250057  서울특별시     서초구    서초동           서울특별시 서초구 서초동 사평대로 376-2
# 132  20250059  서울특별시     동작구    대방동               서울특별시 동작구 대방동 393-62
#
#               sagoLat           sagoLon  sagoDate sinkWidth sinkExtend  ...  \
# 0    37.5132371585627  127.055971939683  20180301      3.00       4.00  ...
# 1    37.5021977560891  127.096494047762  20180304      1.00       2.00  ...
# 2     37.488421596603  126.883472710376  20180311      0.40       0.40  ...
# 3    37.5293098168504  126.894815508944  20180313      0.50       0.70  ...
# 4    37.5356952035028   126.89430452358  20180327      5.00       5.00  ...
# ..                ...               ...       ...       ...        ...  ...
# 128  37.4922748332904  127.043511837517  20250512      1.50       1.20  ...
# 129  37.5917967992063  127.049936318026  20250516      1.00       1.00  ...
# 130  37.5042040311426  127.024123820963  20250507      4.00      10.00  ...
# 131  37.5042040311426  127.024123820963  20250517      1.50       1.50  ...
# 132  37.5004059540793  126.927916516232  20250529      0.80       0.80  ...
#
#     deathCnt injuryCnt vehicleCnt trStatus                        trMethod  \
# 0          0         0          0     복구완료                 한국지역난방공사에서 복구완료
# 1          0         0          0     복구완료                  강동수도사업소에서 복구완료
# 2          0         0          0     복구완료                   KT구로지사에서 복구완료
# 3          0         0          1     복구완료                 영등포구 치수과에서 복구완료
# 4          0         0          1     복구완료                 영등포구 치수과에서 복구완료
# ..       ...       ...        ...      ...                             ...
# 128        0         0          0     임시복구                      라바콘, 모래주머니
# 129        0         0          1     복구완료  기존관 및 신설관 관경 확보하여 수밀밸트로 이음부 보강
# 130        0         0          0     복구완료                아스콘 포설 다짐, 표층 복구
# 131        0         0          1     복구완료                 아스콘 포설 다짐, 표층복구
# 132        0         0          0      복구중                   하수관 교체 및 되메우기
#
#     trAmt  trFnDate  daStDate no       sagoDetailProcessed
# 0       0  20180306  00010101  1  ['노후 지하시설물', '굴착/복구 불량']
# 1       0  20180305  00010101  1                  노후 지하시설물
# 2       0  20180312  00010101  1  ['노후 지하시설물', '굴착/복구 불량']
# 3       0  20180318  00010101  1     ['노후 지하시설물', '지반 약화']
# 4       0  20180507  00010101  1     ['공사 영향', '노후 지하시설물']
# ..    ...       ...       ... ..                       ...
# 128     0  20250512  00010101  1                  굴착/복구 불량
# 129     0  20250516  00010101  1                  설계/시공 오류
# 130     0  20250507  00010101  1                  굴착/복구 불량
# 131     0  20250518  00010101  1                  굴착/복구 불량
# 132     0  20250529  00010101  1                  노후 지하시설물
#
# [133 rows x 23 columns]

# %%
def insert_labels_to_column_tr(df, labels, start_idx=0):
    """
    trMethodProcessed 컬럼에 지정한 라벨 리스트를 해당 인덱스에 맞게 삽입합니다.

    Args:
        df (pd.DataFrame): 원본 DataFrame
        labels (list): 각 행에 삽입할 라벨 리스트
        start_idx (int): 시작 인덱스 (기본값은 0)

    Returns:
        pd.DataFrame: 수정된 DataFrame
    """
    end_idx = start_idx + len(labels)
    
    # 컬럼 없으면 생성
    if "trMethodProcessed" not in df.columns:
        df["trMethodProcessed"] = ""

    for i, label in enumerate(labels):
        df.at[start_idx + i, "trMethodProcessed"] = label

    return df

# %%
import pandas as pd

# 잘림 없이 전체 텍스트 출력 설정
pd.set_option("display.max_colwidth", None)

index = 0
# 예시: 앞 20개만 출력
print(df[["trMethod", "trStatus"]].iloc[index:index + 20])
# Out:
#                 trMethod trStatus
# 0        한국지역난방공사에서 복구완료     복구완료
# 1         강동수도사업소에서 복구완료     복구완료
# 2          KT구로지사에서 복구완료     복구완료
# 3        영등포구 치수과에서 복구완료     복구완료
# 4        영등포구 치수과에서 복구완료     복구완료
# 5        영등포구 치수과에서 복구완료     복구완료
# 6        도봉구 물관리과에서 복구완료     복구완료
# 7         강남구 치수과에서 복구완료     복구완료
# 8         용산구 치수과에서 복구완료     복구완료
# 9         구로구 도로과에서 복구완료     복구완료
# 10        관악구 치수과에서 복구완료     복구완료
# 11        중부수도사업소에서 복구완료     복구완료
# 12  남부도로사업소 도로보수과에서 복구완료     복구완료
# 13      종로구 안전치수과에서 복구완료     복구완료
# 14      강북구 안전치수과에서 복구완료     복구완료
# 15      동작구 안전치수과에서 복구완료     복구완료
# 16       원인자(웰크론한텍㈜)복구완료     복구완료
# 17       강서구 물관리과에서 복구완료     복구완료
# 18           강서구청에서 복구완료     복구완료
# 19         중구 치수과에서 복구완료     복구완료

# %%
df = insert_labels_to_column_tr(df, labels, start_idx=index)
df["trMethodProcessed"].iloc[:]

# %% [markdown]
# ## 날씨 데이터 일시 컬럼 수정

# %%
import pandas as pd

def modify_date_column(filepath):
    # CSV 파일 불러오기
    df = pd.read_csv(filepath)

    # '일시'에서 '-' 제거 → '일시_modified' 컬럼 생성
    df['일시_modified'] = df['일시'].astype(str).str.replace('-', '', regex=False)

    # 동일 파일로 덮어쓰기
    df.to_csv(filepath, index=False, encoding='utf-8-sig')
    print(f"변경된 데이터가 {filepath}에 저장되었습니다.")

# 사용 예시
modify_date_column("sinkhole-visualization/src/data/weather_with_sigungu.csv")
# Out:
# 변경된 데이터가 sinkhole-visualization/src/data/weather_with_sigungu.csv에 저장되었습니다.

# %% [markdown]
# # 특정 지역

# %%
import os
import pandas as pd

def filter_and_save_seoul_rows(input_path: str, output_dir: str):
    # 파일 존재 여부 확인
    if not os.path.exists(input_path):
        print(f"❌ 입력 파일 없음: {input_path}")
        return

    # CSV 로드
    df = pd.read_csv(input_path, dtype=str)

    # sido 컬럼 존재 여부 확인
    if "sido" not in df.columns:
        print("🚨 'sido' 컬럼이 존재하지 않습니다.")
        return

    # '서울특별시'에 해당하는 행 필터링
    seoul_df = df[df["sido"] == "서울특별시"]

    if seoul_df.empty:
        print("⚠️ 서울특별시 데이터가 없습니다.")
        return

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, os.path.basename(input_path))

    # 저장
    seoul_df.to_csv(output_path, index=False, encoding="utf-8-sig")
    print(f"✅ 저장 완료: {output_path}")

# 실행 예시
if __name__ == "__main__":
    input_csv = "Database/openapi/지반침하사고_정보.csv"
    output_folder = "Database/openapi/seoul"
    filter_and_save_seoul_rows(input_csv, output_folder)
# Out:
# ✅ 저장 완료: Database/openapi/seoul/지반침하사고_정보.csv

# %% [markdown]
# ## sinkholes.json에 날씨 추가

# %%
import pandas as pd
import json

# 1. JSON 파일 불러오기
with open('sinkhole-visualization/src/sinkholes.json', 'r', encoding='utf-8') as f:
    sinkholes = json.load(f)

# 2. 날씨 CSV 불러오기
weather_df = pd.read_csv('/Users/yiji/Desktop/YONSEI/데이터 시각화/프로젝트/Lookatme/sinkhole-visualization/src/data/weather_with_sigungu.csv', dtype={'일시_modified': str})

# 3. 병합용 딕셔너리 만들기
weather_map = {
    f"{row['일시_modified']}_{row['sigungu']}": {
        'avgTemp': row['평균기온(°C)'],
        'rainfall': row['일강수량(mm)']
    }
    for _, row in weather_df.iterrows()
}

# 4. 싱크홀 데이터에 날씨 추가
for item in sinkholes:
    date_str = str(item.get('sagoDate'))[:8]
    sigungu = item.get('sigungu', '').strip()
    key = f"{date_str}_{sigungu}"
    weather = weather_map.get(key)

    if weather:
        item['avgTemp'] = weather['avgTemp']
        item['rainfall'] = weather['rainfall']
    else:
        item['avgTemp'] = None
        item['rainfall'] = None

# 5. 결과 저장
with open('/Users/yiji/Desktop/YONSEI/데이터 시각화/프로젝트/Lookatme/sinkhole-visualization/src/sinkholes.json', 'w', encoding='utf-8') as f:
    json.dump(sinkholes, f, ensure_ascii=False, indent=2)

print("✅ 병합 완료! → sinkholes.json")
# Out:
# ✅ 병합 완료! → sinkholes.json

# %%
import pandas as pd
import json
import numpy as np

# 기존 sinkhole 데이터 로드
with open('sinkhole-visualization/src/sinkholes.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# 혹시 DataFrame으로 다루고 있다면:
df = pd.DataFrame(data)

# NaN 값을 None으로 변환
df = df.replace({np.nan: None})

# 다시 JSON 저장
with open('sinkhole-visualization/src/sinkholes.json', 'w', encoding='utf-8') as f:
    json.dump(df.to_dict(orient='records'), f, ensure_ascii=False, indent=2)

# %% [markdown]
# # EDA

# %%
df["grdKind"].unique()
# Out:
# array([nan, '호상편마암', '기타', '충척층'], dtype=object)

# %%
df["grdKind"].isna().sum()
# Out:
# 92

# %%
df[df["grdKind"] == "충척층"].count()
# Out:
# sagoNo                 1
# sido                   1
# sigungu                1
# dong                   1
# addr                   1
# sagoLat                1
# sagoLon                1
# sagoDate               1
# sinkWidth              1
# sinkExtend             1
# sinkDepth              1
# grdKind                1
# sagoDetail             1
# deathCnt               1
# injuryCnt              1
# vehicleCnt             1
# trStatus               1
# trMethod               1
# trAmt                  1
# trFnDate               1
# daStDate               1
# no                     1
# sagoDetailProcessed    1
# dtype: int64

# %%
df["trStatus"].unique()
# Out:
# array(['복구완료', '임시복구', '복구중'], dtype=object)

# %%
df["trAmt"].unique()
# Out:
# array(['0', '20000000', '3000000', '350000000', '5000000', '4000000',
#        '1000000', '2000000'], dtype=object)

# %%
df[df["trAmt"] == "0"].count()
# Out:
# sagoNo                 123
# sido                   123
# sigungu                123
# dong                   113
# addr                   123
# sagoLat                123
# sagoLon                123
# sagoDate               123
# sinkWidth              123
# sinkExtend             123
# sinkDepth              123
# grdKind                 32
# sagoDetail             121
# deathCnt               123
# injuryCnt              123
# vehicleCnt             123
# trStatus               123
# trMethod               123
# trAmt                  123
# trFnDate               123
# daStDate               123
# no                     123
# sagoDetailProcessed    123
# dtype: int64

# %%
df["trFnDate"].unique()
# Out:
# array(['20180306', '20180305', '20180312', '20180318', '20180507',
#        '20180328', '20180426', '20180525', '20180429', '20180624',
#        '20180717', '20180815', '20180905', '20181202', '20181219',
#        '20190425', '20190728', '20190803', '20190806', '20190808',
#        '20190814', '20190907', '20190911', '20190912', '20190917',
#        '20190922', '20191127', '20191224', '20200108', '20200306',
#        '20200512', '20200313', '20200515', '20200522', '20200917',
#        '20201116', '20200922', '20200810', '20200820', '20200829',
#        '20200812', '20200818', '20200724', '20210331', '20210309',
#        '20210407', '20210609', '20210806', '20210704', '20210728',
#        '20210826', '20210821', '20210905', '20220218', '20220128',
#        '20220124', '20220624', '20220629', '20220701', '20220718',
#        '20220706', '20220710', '20220810', '20220809', '20220814',
#        '20220818', '20221004', '20221119', '20221210', '20230102',
#        '20230113', '20230217', '20230308', '20230313', '20230331',
#        '20230408', '20230412', '20230506', '20230611', '20230627',
#        '20230612', '20230712', '20230720', '20230727', '20230806',
#        '20230811', '20230911', '20230912', '20231012', '20231026',
#        '20231103', '20231209', '20240104', '20240116', '20240223',
#        '20240502', '20240714', '20240722', '20240805', '20240829',
#        '20240828', '20240830', '20240831', '20240901', '20240908',
#        '20240913', '20241107', '20241028', '20250317', '20250305',
#        '20250116', '20250306', '20250430', '20250117', '20250401',
#        '20250417', '20250424', '20250429', '20250420', '20250427',
#        '20250426', '20250512', '20250516', '20250507', '20250518',
#        '20250529'], dtype=object)

# %%
df[df["sagoDetailProcessed"].str.contains("지반 약화", na=False)].count()
# Out:
# sagoNo                 27
# sido                   27
# sigungu                27
# dong                   26
# addr                   27
# sagoLat                27
# sagoLon                27
# sagoDate               27
# sinkWidth              27
# sinkExtend             27
# sinkDepth              27
# grdKind                 5
# sagoDetail             27
# deathCnt               27
# injuryCnt              27
# vehicleCnt             27
# trStatus               27
# trMethod               27
# trAmt                  27
# trFnDate               27
# daStDate               27
# no                     27
# sagoDetailProcessed    27
# dtype: int64

# %%
df["sagoDetailProcessed"].unique()
# Out:
# array(["['노후 지하시설물', '굴착/복구 불량']", '노후 지하시설물', "['노후 지하시설물', '지반 약화']",
#        "['공사 영향', '노후 지하시설물']", '설계/시공 오류', "['설계/시공 오류', '지반 약화']",
#        "['공사 영향', '굴착/복구 불량']", '굴착/복구 불량', '지하시설물 영향',
#        "['공사 영향', '설계/시공 오류']", '기타 / 미상',
#        "['노후 지하시설물', '설계/시공 오류', '자연재해']", "['공사 영향', '자연재해', '지반 약화']",
#        "['노후 지하시설물', '지반 약화', '기타 / 미상']", '지반 약화',
#        "['노후 지하시설물', '설계/시공 오류']", "['공사 영향', '지반 약화']",
#        "['공사 영향', '노후 지하시설물', '설계/시공 오류']", "['설계/시공 오류', '기타 / 미상']",
#        "['자연재해', '설계/시공 오류', '지반 약화']", "['설계/시공 오류', '공사 영향']",
#        "['노후 지하시설물', '공사 영향']", '공사 영향', "['공사 영향', '기타 / 미상']",
#        '원인불명/기타', "['자연재해', '노후 지하시설물']", "['공사 영향', '자연재해']",
#        "['자연재해', '설계/시공 오류']", "['노후 지하시설물', '자연재해']", '자연재해'],
#       dtype=object)
